# %% [markdown]
# # Actor-Critic Agents
#
# Ahora trabajaremos con los algoritmos de gradiente de política: Advantage Actor-Critic (A2C) y Soft Actor-Critic (SAC). Estudiaremos ambos algoritmos usando las implementaciones incluidas dentro de <a href="https://stable-baselines3.readthedocs.io/en/master/index.html">Stable Baselines3</a>, y los usaremos para resolver dos problemas de robótica basados en el entorno de simulación MuJoCo: <a href="https://gymnasium.farama.org/environments/mujoco/hopper/">Hopper</a> y <a href="https://gymnasium.farama.org/environments/mujoco/ant/">Ant</a>.

# %% [markdown]
# # Instalación de Librerías
#
# Antes de comenzar, se sugiere elegir un entorno de simulación acelerado por GPU. En el caso de Colab gratuito, debería elegir el entorno de T4. Para ello diríjase a:
#
# `Entorno de Ejecución > Cambiar Tipo de Entorno de Ejecución > GPU T4`
#
#
# ![DobleDQNdF](runtime.png)
#
#
# Después, ejecute el siguiente bloque de código para instalar todas las librerías y herramientas necesarias.

# %% [markdown]
# Corra el siguiente bloque de código para instalar las librerías requeridas en el tutorial. Se encuentra incluído el módulo oficial de Stable Baselines3 que ejecuta A2C y SAC, y los ambientes de Gymnasium que incluyen Hopper y Ant. Esta celda puede tardar un par de minutos en ejecutarse completamente la primera vez.

# %%
import sys
_IS_WINDOWS = sys.platform.startswith('win')
try:
    if _IS_WINDOWS:
        raise RuntimeError('pyvirtualdisplay requiere Xvfb (Linux/Colab)')
    from pyvirtualdisplay import Display  # type: ignore
    _HAS_VDISPLAY = True
except Exception:
    _HAS_VDISPLAY = False
    class Display:  # stub para Windows; en Colab/Linux funciona el real
        def __init__(self, *args, **kwargs):
            pass
        def start(self):
            return self
        def stop(self):
            pass

from IPython.display import HTML
from base64 import b64encode

import gymnasium as gym
import imageio
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
import time

from stable_baselines3 import SAC, A2C
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

from IPython.display import clear_output
clear_output()
print('Librerias cargadas. Display virtual disponible:', _HAS_VDISPLAY)
# Out:
# Librerias cargadas. Display virtual disponible: False

# %% [markdown]
# # Familiarización con los Entornos de Gym
#
# Los siguientes ambientes de Gymnasium son entornos basados en MuJoCo de Google Deep Mind. MuJoCo (Multi-Joint dynamics with Contact) es un simulador físico utilizado para modelar y estudiar el comportamiento de sistemas dinámicos complejos, muy utilizado en robótica.

# %% [markdown]
# ## Inverted Pendulum
#
# El ambiente de <a href="https://gymnasium.farama.org/environments/mujoco/inverted_pendulum/">Inverted Pendulum</a> corresponde al ambiente de Cartpole, basado en el trabajo de Barto, Sutton y Anderson en “Neuronlike adaptive elements that can solve difficult learning control problems”, al igual que en los ambientes clásicos, pero ahora impulsado por el simulador físico MuJoCo, lo que permite experimentos más complejos (como variar los efectos de la gravedad). Este ambiente consiste en un carro que puede moverse linealmente, con un péndulo unido a un extremo y el otro extremo libre. El carro puede ser empujado hacia la izquierda o la derecha, y el objetivo es equilibrar el péndulo sobre el carro aplicando fuerzas al mismo.
#
# ![image.png](data:image/png;base64,...)
#
# <center>Figura 1. Descripción del ambiente de Inverted Pendulum. [4]</center>
#
# Como se puedes ver en la Figura 1, el espacio de acciones de este entorno es continuo y consiste en un vector de una dimensión con valores entre -3 y 3. Esta acción representa la fuerza aplicada al carro: su magnitud indica la intensidad y su signo la dirección (positiva hacia la derecha, negativa hacia la izquierda). El espacio de observación está compuesto por cuatro valores: la posición del carro, el ángulo del péndulo respecto a la vertical, la velocidad lineal del carro y la velocidad angular del péndulo. Cada uno de estos valores puede tomar cualquier número real. En cuanto a las recompensas, el agente recibe +1 por cada paso de tiempo en el que el péndulo se mantiene en posición vertical, es decir, dentro de un ángulo menor a 0.2 radianes respecto a la vertical. El objetivo es maximizar esta recompensa manteniendo el equilibrio del péndulo el mayor tiempo posible.

# %% [markdown]
# ### Ejemplo

# %% [markdown]
# En el siguiente bloque de código se muestra un ejemplo de cómo se simula un episodio del CartPole. En este caso siempre se toma la acción de ir a la derecha con una fuerza de 0.05 N.

# %%
# Start a virtual display (needed in Colab or headless)
display = Display(visible=0, size=(1400, 900))
display.start()

# Create Hopper environment with RGB rendering
env = gym.make("InvertedPendulum-v5", render_mode="rgb_array")
obs, info = env.reset()

frames = []
terminated = truncated = False
total_reward = 0

while not (terminated or truncated):
    action = [0.05]
    obs, reward, terminated, truncated, info = env.step(action)
    frame = env.render()
    frames.append(frame)
    total_reward += reward

env.close()

# Save video
imageio.mimsave("ip_video_rigth.mp4", frames, fps=30)
print("Total reward:", total_reward)
# Out:
# Total reward: 12

# %%
mp4 = open("ip_video_rigth.mp4", "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=600 controls>
    <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# <video width=600 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
#  ### Ejercicio práctico 1
#
#
# Para comprobar el entendimiento de la simulación, modifique el ejemplo anterior cambiando la acción. Simule el ambiente donde la acción se escoja aleatoriamente entre izquierda y derecha, con una fuerza dentro del rango posible, (recuerde utilizar la función reset() antes de comenzar un nuevo episodio).

# %%
# Ejercicio practico 1: accion aleatoria en InvertedPendulum
display = Display(visible=0, size=(1400, 900))
display.start()

env = gym.make("InvertedPendulum-v5", render_mode="rgb_array")
obs, info = env.reset(seed=42)

frames = []
terminated = truncated = False
total_reward = 0

# Espacio de accion: Box(-3.0, 3.0, (1,)) -> fuerza horizontal sobre el carro
low, high = env.action_space.low[0], env.action_space.high[0]

while not (terminated or truncated):
    # Signo aleatorio (izquierda/derecha) y magnitud uniforme dentro del rango
    action = np.array([np.random.uniform(low, high)], dtype=np.float32)
    obs, reward, terminated, truncated, info = env.step(action)
    frame = env.render()
    frames.append(frame)
    total_reward += reward

env.close()

imageio.mimsave("ip_video_random.mp4", frames, fps=30)
print("Total reward (IP, accion aleatoria):", total_reward)
print("Pasos del episodio:", len(frames))
# Out:
# Total reward (IP, accion aleatoria): 4
# Pasos del episodio: 5

# %%
mp4 = open("ip_video_random.mp4", "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=600 controls>
    <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# <video width=600 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# ## Inverted Double Pendulum
#
# El ambiente de <a href="https://gymnasium.farama.org/environments/mujoco/inverted_double_pendulum/">Inverted Double Pendulum</a>  consiste en un carro que puede moverse linealmente, con un primer péndulo unido a él y un segundo péndulo conectado al extremo libre del primero (dejando al segundo péndulo con un extremo libre). El carro puede ser empujado hacia la izquierda o la derecha, y el objetivo es equilibrar el segundo péndulo sobre el primero, que a su vez está sobre el carro, aplicando fuerzas continuas al carro.
#
# ![image.png](data:image/png;base64,...)
#
# <center>Figura 2. Descripción del ambiente de Inverted Double Pendulum. [5]</center>
#
# El espacio de acciones de este ambiente es continuo y está representado por un vector unidimensional con valores entre -1 y 1. Esta acción corresponde a la fuerza aplicada al carro, donde la magnitud indica la intensidad y el signo la dirección (positiva hacia la derecha, negativa hacia la izquierda). El espacio de observaciones está compuesto por 9 elementos: la posición del carro, el seno y coseno de los ángulos de los dos péndulos, las velocidades lineales y angulares de las partes móviles, y una fuerza de restricción aplicada por el simulador. Estos valores permiten al agente percibir el estado completo del sistema físico. En cuanto a las recompensas, el agente recibe una recompensa positiva constante por cada paso en el que logra mantener el segundo péndulo en equilibrio sobre el primero, incentivando así el aprendizaje de una política que maximice la estabilidad del sistema durante el mayor tiempo posible.

# %% [markdown]
# ### Ejemplo

# %% [markdown]
# En el siguiente bloque de código se muestra un ejemplo de cómo se simula un episodio de DoublePendulum. En este caso siempre se toma la acción de ir a la derecha con una fuerza de 0.05 N.

# %%
# Start a virtual display (needed in Colab or headless)
display = Display(visible=0, size=(1400, 900))
display.start()

# Create Hopper environment with RGB rendering
env = gym.make("InvertedDoublePendulum-v5", render_mode="rgb_array")
obs, info = env.reset()

frames = []
terminated = truncated = False
total_reward = 0

while not (terminated or truncated):
    action = [0.05]
    obs, reward, terminated, truncated, info = env.step(action)
    frame = env.render()
    frames.append(frame)
    total_reward += reward

env.close()

# Save video
imageio.mimsave("idp_video_rigth.mp4", frames, fps=30)
print("Total reward:", total_reward)
# Out:
# Total reward: 101.11805907206923

# %%
mp4 = open("idp_video_rigth.mp4", "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=600 controls>
    <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# <video width=600 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# ### Ejercicio práctico 2
#
#
# Para comprobar el entendimiento de la simulación, modifique el ejemplo anterior cambiando la acción. Simule el ambiente donde la acción se escoja aleatoriamente entre izquierda y derecha, con una fuerza dentro del rango posible, (recuerde utilizar la función reset() antes de comenzar un nuevo episodio).

# %%
# Ejercicio practico 2: accion aleatoria en InvertedDoublePendulum
display = Display(visible=0, size=(1400, 900))
display.start()

env = gym.make("InvertedDoublePendulum-v5", render_mode="rgb_array")
obs, info = env.reset(seed=42)

frames = []
terminated = truncated = False
total_reward = 0

# Espacio de accion: Box(-1.0, 1.0, (1,)) -> fuerza normalizada
low, high = env.action_space.low[0], env.action_space.high[0]

while not (terminated or truncated):
    action = np.array([np.random.uniform(low, high)], dtype=np.float32)
    obs, reward, terminated, truncated, info = env.step(action)
    frame = env.render()
    frames.append(frame)
    total_reward += reward

env.close()

imageio.mimsave("idp_video_random.mp4", frames, fps=30)
print("Total reward (IDP, accion aleatoria):", total_reward)
print("Pasos del episodio:", len(frames))
# Out:
# Total reward (IDP, accion aleatoria): 72.95730199697059
# Pasos del episodio: 9

# %%
mp4 = open("idp_video_random.mp4", "rb").read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=600 controls>
    <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# <video width=600 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# # A2C
#
#
# Recordemos el funcionamiento de los algoritmos de gradiente de política en el aprendizaje por refuerzo. Estos algoritmos, en lugar de realizar una estimación de la función de valor $Q(s,a)$, estiman directamente una política $\pi(s,a,\theta)$ y la mejoran continuamente mediante un proceso de optimización numérica basada en ascenso de gradiente. Uno de estos algoritmos es REINFORCE, estudiado anteriormente en la Tarea de la Semana 4. En este algoritmo, se podía utilizar un <i>baseline</i> para reducir la varianza del entrenamiento. En este escenario, la actualización de REINFORCE está dada por la Ecuación (1):
#
# $\theta_{t+1} \doteq \theta_t + \alpha (G_t-b(S_t)) \frac{\nabla \pi(A_t | S_t, \theta_t)}{\pi(A_t | S_t, \theta_t)}$ &emsp;&emsp;&emsp;$(1)$
#
# Una selección común para este <i>baseline</i> es un estimativo adicional de la función de valor de estado $V(s)$. Cuando se usa una función de valor como <i>baseline</i>, el término $G_t-b(S_t)$ se transforma en un estimativo de la ventaja (<i>advantage</i>) de la acción $A_t$ en el estado $S_t$. El retorno $G_t$ funciona como un estimador de $Q(S_t,A_t)$, y como el <i>baseline</i> es un estimativo de $V(S_t)$, se define la ventaja formalmente como aparece en la Ecuación (2):
#
# $A(S_t,A_t) = Q(S_t,A_t) - V(S_t)$ &emsp;&emsp;&emsp;$(2)$
#
# Esta aproximación puede ser vista como una arquitectura actor-crítico, donde la política $\pi$ es el actor que efectúa las acciones, y el <i>baseline</i> es el crítico que evalúa el resultado de dichas acciones. Esta estrategia incorpora un <i>bootstrapping</i> que reduce la varianza al mínimo posible, a costa de introducir un sesgo. La Ecuación (2) sugiere incrementar la probabilidad de las acciones mejor que el promedio, y disminuir la probabilidad de las acciones peores al promedio.
#
# Vale la pena mencionar que el algoritmo Advantage Actor-Critic (A2C) es una versión posterior y sincrónica del algoritmo Asynchronous Advantage Actor-Critic (A3C). En la publicación original [2], A3C es un algoritmo que se formula como una versión asincrónica de un algoritmo actor-crítico, que en lugar de usar <i>experience replay</i>, entrena múltiples agentes en varios hilos de CPU, siendo así una aproximación on-policy más rápida y eficiente computacionalmente. A2C en cambio es la versión síncrona, que no usa agentes en paralelo y puede ser mejor para implementar en GPU. En [2] se muestra que la estimación de la ventaja está dada por la Ecuación (3). En los algoritmos actor-crítico es común utilizar una red neuronal para la estimación de la política y otra red distinta para la estimación de la ventaja, por lo cual se usa la notación $\theta$ para referirse a los parámetros de la red del actor, y $\theta_v$ para la red del crítico.
#
# $A(S_t,A_t, \theta, \theta_v) = \sum_{i=0}^{k-1} \gamma^i R_{t+i} + \gamma^k V(S_{t+k}, \theta_v) - V(s_t, \theta_v)$ &emsp;&emsp;&emsp;$(3)$

# %% [markdown]
# ## Entrenamiento de agentes A2C para Inverted Pendulum

# %% [markdown]
# En la siguiente celda de código se encuentra la clase encargada del entrenamiento de agentes para el ambiente de Inverted Pendulum

# %%
# Clase personalizada para registrar las recompensas por episodio durante el entrenamiento
class RewardLoggerCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []  # Lista para almacenar las recompensas por episodio
        self.episode_reward = 0    # Acumulador de recompensa para el episodio actual

    def _on_step(self) -> bool:
        # Si hay recompensas disponibles en el paso actual, se suman al acumulador
        if "rewards" in self.locals:
            self.episode_reward += self.locals["rewards"][0]
        # Si el episodio ha terminado, se guarda la recompensa acumulada y se reinicia el contador
        if "dones" in self.locals and self.locals["dones"][0]:
            self.episode_rewards.append(self.episode_reward)
            self.episode_reward = 0
        return True


# Clase para entrenar un agente en el entorno Inverted Pendulum
class IPTrainer:
    def __init__(self, model_fn, total_timesteps=130_000, log_dir="./IP_logs"):
        self.total_timesteps = total_timesteps
        self.log_dir = log_dir
        os.makedirs(log_dir, exist_ok=True)  # Crear el directorio de logs si no existe

        # Iniciar una pantalla virtual (necesaria en Colab o entornos sin interfaz gráfica)
        self.display = Display(visible=0, size=(1400, 900))
        self.display.start()

        # Crear el entorno Inverted Pendulum vectorizado
        self.env = make_vec_env("InvertedPendulum-v5", n_envs=1)

        # Crear el modelo usando la función proporcionada
        self.model = model_fn(self.env)

        # Inicializar el callback para registrar recompensas
        self.callback = RewardLoggerCallback()


    def train(self, save_path="a2c_ip_model"):
        print("GPU available?", torch.cuda.is_available())
        if torch.cuda.is_available():
            print("Using device:", torch.cuda.get_device_name(0))

        start_time = time.time()
        # Entrenar el modelo con el número total de pasos y el callback
        self.model.learn(total_timesteps=self.total_timesteps, callback=self.callback)
        elapsed = time.time() - start_time

        # Guardar el modelo entrenado
        self.model.save(save_path)
        print(f"Training complete. Model saved. Training took {elapsed:.2f} seconds.")

    def plot_rewards(self):
        # Verificar si hay datos de recompensa para graficar
        if not self.callback.episode_rewards:
            print("No reward data to plot.")
            return
        # Graficar las recompensas por episodio
        plt.figure(figsize=(10, 5))
        plt.plot(self.callback.episode_rewards, label="Episode Reward")
        plt.xlabel("Episodes")
        plt.ylabel("Reward")
        plt.title("Training Rewards Over Time")
        plt.grid()
        plt.legend()
        plt.tight_layout()
        plt.show()

    def generate_video(self, model, video_filename="hopper_video.mp4"):
        # Crear entorno Inverted Double Pendulum con renderizado RGB
        env = gym.make("InvertedPendulum-v5", render_mode="rgb_array")
        obs, info = env.reset()
        frames = []
        total_reward = 0
        terminated = truncated = False

        # Ejecutar el entorno hasta que termine
        while not (terminated or truncated):
            action, _ = model.predict(obs, deterministic=True)  # Predecir acción
            obs, reward, terminated, truncated, info = env.step(action)
            frame = env.render()  # Capturar fotograma
            frames.append(frame)
            total_reward += reward

        env.close()

        # Guardar el video como archivo MP4
        imageio.mimsave(video_filename, frames, fps=30)
        print("Total reward:", total_reward)

        # Mostrar el video en Colab
        mp4 = open(video_filename, "rb").read()
        data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

        return HTML(f"""
        <video width=600 controls>
            <source src="{data_url}" type="video/mp4">
        </video>
        """)

# %%
# Clase para entrenar un agente en el entorno Inverted Double Pendulum
class IDPTrainer:
    def __init__(self, model_fn, total_timesteps=130_000, log_dir="./IP_logs"):
        self.total_timesteps = total_timesteps
        self.log_dir = log_dir
        os.makedirs(log_dir, exist_ok=True)  # Crear el directorio de logs si no existe

        # Iniciar una pantalla virtual (necesaria en Colab o entornos sin interfaz gráfica)
        self.display = Display(visible=0, size=(1400, 900))
        self.display.start()

        # Crear el entorno Inverted Double Pendulum vectorizado
        self.env = make_vec_env("InvertedDoublePendulum-v5", n_envs=1)

        # Crear el modelo usando la función proporcionada
        self.model = model_fn(self.env)

        # Inicializar el callback para registrar recompensas
        self.callback = RewardLoggerCallback()


    def train(self, save_path="a2c_ip_model"):
        print("GPU available?", torch.cuda.is_available())
        if torch.cuda.is_available():
            print("Using device:", torch.cuda.get_device_name(0))

        start_time = time.time()
        # Entrenar el modelo con el número total de pasos y el callback
        self.model.learn(total_timesteps=self.total_timesteps, callback=self.callback)
        elapsed = time.time() - start_time

        # Guardar el modelo entrenado
        self.model.save(save_path)
        print(f"Training complete. Model saved. Training took {elapsed:.2f} seconds.")

    def plot_rewards(self):
        # Verificar si hay datos de recompensa para graficar
        if not self.callback.episode_rewards:
            print("No reward data to plot.")
            return
        # Graficar las recompensas por episodio
        plt.figure(figsize=(10, 5))
        plt.plot(self.callback.episode_rewards, label="Episode Reward")
        plt.xlabel("Episodes")
        plt.ylabel("Reward")
        plt.title("Training Rewards Over Time")
        plt.grid()
        plt.legend()
        plt.tight_layout()
        plt.show()

    def generate_video(self, model, video_filename="hopper_video.mp4"):
        # Crear entorno Inverted Double Pendulum con renderizado RGB
        env = gym.make("InvertedDoublePendulum-v5", render_mode="rgb_array")
        obs, info = env.reset()
        frames = []
        total_reward = 0
        terminated = truncated = False

        # Ejecutar el entorno hasta que termine
        while not (terminated or truncated):
            action, _ = model.predict(obs, deterministic=True)  # Predecir acción
            obs, reward, terminated, truncated, info = env.step(action)
            frame = env.render()  # Capturar fotograma
            frames.append(frame)
            total_reward += reward

        env.close()

        # Guardar el video como archivo MP4
        imageio.mimsave(video_filename, frames, fps=30)
        print("Total reward:", total_reward)

        # Mostrar el video en Colab
        mp4 = open(video_filename, "rb").read()
        data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

        return HTML(f"""
        <video width=600 controls>
            <source src="{data_url}" type="video/mp4">
        </video>
        """)

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# En la siguiente celda se muestra el entrenamiento y los resultados para un agente A2C durante 100000 interacciones con el ambiente

# %%
def create_model(env):
    return A2C(
        "MlpPolicy",
        env,
        verbose=1,
        device="cuda"
    )

trainer = IPTrainer(model_fn=create_model, total_timesteps=100_000)
trainer.train(save_path="a2c_ip_model")
# Out:
# Using cuda device
# c:\Users\ASUS\Desktop\Andes\Maestria\reinforcement-learning\venv\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# GPU available? True
# Using device: NVIDIA GeForce RTX 4060 Laptop GPU
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.5     |
# |    ep_rew_mean        | 12.5     |
# | time/                 |          |
# |    fps                | 213      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.0324   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 4.91     |
# |    std                | 1.01     |
# |    value_loss         | 10.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.8     |
# |    ep_rew_mean        | 18.8     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.104    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 3.06     |
# |    std                | 0.993    |
# |    value_loss         | 7.08     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.9     |
# |    ep_rew_mean        | 22.9     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.174   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 4.85     |
# |    std                | 0.974    |
# |    value_loss         | 7.56     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.7     |
# |    ep_rew_mean        | 26.7     |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.00508  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 2.62     |
# |    std                | 0.975    |
# |    value_loss         | 5.92     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.6     |
# |    ep_rew_mean        | 29.6     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.0131  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 3.38     |
# |    std                | 0.975    |
# |    value_loss         | 5.29     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 34.3     |
# |    ep_rew_mean        | 33.3     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.0126   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 2.26     |
# |    std                | 0.97     |
# |    value_loss         | 4.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.3     |
# |    ep_rew_mean        | 36.3     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.00121  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.99     |
# |    std                | 0.961    |
# |    value_loss         | 4.1      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 40.2      |
# |    ep_rew_mean        | 39.2      |
# | time/                 |           |
# |    fps                | 268       |
# |    iterations         | 800       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -0.000414 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 1.77      |
# |    std                | 0.962     |
# |    value_loss         | 3.59      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.2     |
# |    ep_rew_mean        | 43.2     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 900      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -3.9e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.49     |
# |    std                | 0.96     |
# |    value_loss         | 3.1      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.1     |
# |    ep_rew_mean        | 48.1     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.00138  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -16.9    |
# |    std                | 0.95     |
# |    value_loss         | 987      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.4     |
# |    ep_rew_mean        | 52.4     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.0525   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.76     |
# |    std                | 0.948    |
# |    value_loss         | 2.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 56.5     |
# |    ep_rew_mean        | 55.5     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.0134   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 1.76     |
# |    std                | 0.956    |
# |    value_loss         | 1.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 57.7     |
# |    ep_rew_mean        | 56.7     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 1300     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.176    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 1.66     |
# |    std                | 0.955    |
# |    value_loss         | 1.65     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 59.2     |
# |    ep_rew_mean        | 58.2     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 1400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.093    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -49.5    |
# |    std                | 0.942    |
# |    value_loss         | 2.9e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 60.6     |
# |    ep_rew_mean        | 59.6     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 1500     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | -0.0133  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.903    |
# |    std                | 0.929    |
# |    value_loss         | 1.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 63.7     |
# |    ep_rew_mean        | 62.7     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 1600     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.0203   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.948    |
# |    std                | 0.917    |
# |    value_loss         | 0.782    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 66.3     |
# |    ep_rew_mean        | 65.3     |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 1700     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | -0.015   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.678    |
# |    std                | 0.917    |
# |    value_loss         | 0.565    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 69.7     |
# |    ep_rew_mean        | 68.7     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 1800     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.00015 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.523    |
# |    std                | 0.92     |
# |    value_loss         | 0.367    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.2     |
# |    ep_rew_mean        | 72.2     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 1900     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.00472  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.705    |
# |    std                | 0.923    |
# |    value_loss         | 0.221    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.5     |
# |    ep_rew_mean        | 73.5     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 2000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.0101   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.465    |
# |    std                | 0.916    |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.3     |
# |    ep_rew_mean        | 75.3     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 2100     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | -0.0028  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.226    |
# |    std                | 0.905    |
# |    value_loss         | 0.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.6     |
# |    ep_rew_mean        | 76.6     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 2200     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.000404 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0565   |
# |    std                | 0.896    |
# |    value_loss         | 0.00513  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.7     |
# |    ep_rew_mean        | 78.7     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 2300     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | -0.231   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0045   |
# |    std                | 0.897    |
# |    value_loss         | 1.12e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.3     |
# |    ep_rew_mean        | 80.3     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 2400     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -55.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0527  |
# |    std                | 0.891    |
# |    value_loss         | 0.00317  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.3     |
# |    ep_rew_mean        | 80.3     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 2500     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.00156  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.012    |
# |    std                | 0.897    |
# |    value_loss         | 0.000148 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.7     |
# |    ep_rew_mean        | 81.7     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 2600     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.337    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.00441  |
# |    std                | 0.887    |
# |    value_loss         | 6.82e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.7     |
# |    ep_rew_mean        | 81.7     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 2700     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | -0.0208  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00353  |
# |    std                | 0.882    |
# |    value_loss         | 1.92e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.8     |
# |    ep_rew_mean        | 83.8     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 2800     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -2.68    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.0113   |
# |    std                | 0.884    |
# |    value_loss         | 6.63e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.1     |
# |    ep_rew_mean        | 85.1     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 2900     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.00452 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0037   |
# |    std                | 0.886    |
# |    value_loss         | 5.27e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.4     |
# |    ep_rew_mean        | 87.4     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.11    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0007   |
# |    std                | 0.888    |
# |    value_loss         | 5.97e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.4     |
# |    ep_rew_mean        | 91.4     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 3100     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.0107  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00305  |
# |    std                | 0.891    |
# |    value_loss         | 7.31e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.3     |
# |    ep_rew_mean        | 94.3     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 3200     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.0469  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.00109  |
# |    std                | 0.892    |
# |    value_loss         | 1.27e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 97.5      |
# |    ep_rew_mean        | 96.5      |
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3300      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -1.29     |
# |    explained_variance | -0.000131 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 0.00226   |
# |    std                | 0.883     |
# |    value_loss         | 5.67e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 100      |
# |    ep_rew_mean        | 99.1     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 3400     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.388   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00159  |
# |    std                | 0.888    |
# |    value_loss         | 3.22e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 103      |
# |    ep_rew_mean        | 102      |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 3500     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -1.16    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -3e-05   |
# |    std                | 0.891    |
# |    value_loss         | 3.34e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 105      |
# |    ep_rew_mean        | 104      |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 3600     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | -0.313   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.00305  |
# |    std                | 0.88     |
# |    value_loss         | 1.1e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 105      |
# |    ep_rew_mean        | 104      |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 3700     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -2.16    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.00852 |
# |    std                | 0.889    |
# |    value_loss         | 3.53e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 102      |
# |    ep_rew_mean        | 101      |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 3800     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -406     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -7.43    |
# |    std                | 0.884    |
# |    value_loss         | 227      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.6     |
# |    ep_rew_mean        | 94.6     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 3900     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | -0.00376 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0318   |
# |    std                | 0.876    |
# |    value_loss         | 0.00023  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.2     |
# |    ep_rew_mean        | 91.2     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 4000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | -0.408   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0391   |
# |    std                | 0.881    |
# |    value_loss         | 0.00122  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80.2      |
# |    ep_rew_mean        | 79.2      |
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 4100      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -1.28     |
# |    explained_variance | -0.000565 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | 0.0113    |
# |    std                | 0.874     |
# |    value_loss         | 8.42e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.6     |
# |    ep_rew_mean        | 73.6     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 4200     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.0106   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.00838  |
# |    std                | 0.876    |
# |    value_loss         | 5.88e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.4     |
# |    ep_rew_mean        | 72.4     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 4300     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | -18.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 9.73     |
# |    std                | 0.879    |
# |    value_loss         | 201      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 69.3     |
# |    ep_rew_mean        | 68.3     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 4400     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | -0.0155  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -23.6    |
# |    std                | 0.873    |
# |    value_loss         | 2e+03    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 63.3     |
# |    ep_rew_mean        | 62.3     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 4500     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.217    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 36.4     |
# |    std                | 0.873    |
# |    value_loss         | 3.07e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.5     |
# |    ep_rew_mean        | 52.5     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4600     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -142     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0235   |
# |    std                | 0.862    |
# |    value_loss         | 0.00725  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.8     |
# |    ep_rew_mean        | 43.8     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 4700     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -55      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.016    |
# |    std                | 0.859    |
# |    value_loss         | 0.000356 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 41.7      |
# |    ep_rew_mean        | 40.7      |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 4800      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -1.27     |
# |    explained_variance | -9.13e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 0.951     |
# |    std                | 0.862     |
# |    value_loss         | 1.37      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.2     |
# |    ep_rew_mean        | 41.2     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4900     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -589     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -2.41    |
# |    std                | 0.865    |
# |    value_loss         | 39.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.1     |
# |    ep_rew_mean        | 41.1     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 5000     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -225     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -38.1    |
# |    std                | 0.861    |
# |    value_loss         | 1.26e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41       |
# |    ep_rew_mean        | 40       |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 5100     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -254     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -20.3    |
# |    std                | 0.859    |
# |    value_loss         | 327      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41       |
# |    ep_rew_mean        | 40       |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 5200     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -56.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -10.3    |
# |    std                | 0.859    |
# |    value_loss         | 47.4     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 42.6      |
# |    ep_rew_mean        | 41.6      |
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 5300      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -1.38e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 2.99      |
# |    std                | 0.852     |
# |    value_loss         | 11.2      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.5     |
# |    ep_rew_mean        | 43.5     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 5400     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | -61.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.201    |
# |    std                | 0.855    |
# |    value_loss         | 0.0806   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46       |
# |    ep_rew_mean        | 45       |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 5500     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | -11.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -1.04    |
# |    std                | 0.855    |
# |    value_loss         | 4.74     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.8     |
# |    ep_rew_mean        | 45.8     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 5600     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -351     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 2.59     |
# |    std                | 0.866    |
# |    value_loss         | 22.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.6     |
# |    ep_rew_mean        | 45.6     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 5700     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.783    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -33.4    |
# |    std                | 0.866    |
# |    value_loss         | 1.12e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.4     |
# |    ep_rew_mean        | 43.4     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 5800     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | -3.93    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -5.41    |
# |    std                | 0.874    |
# |    value_loss         | 15.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.2     |
# |    ep_rew_mean        | 38.2     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 5900     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | -4.62    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -4.7     |
# |    std                | 0.872    |
# |    value_loss         | 20.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24       |
# |    ep_rew_mean        | 23       |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 6000     |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | -2.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.368    |
# |    std                | 0.875    |
# |    value_loss         | 3.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.7     |
# |    ep_rew_mean        | 13.7     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 6100     |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.491    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -4.61    |
# |    std                | 0.879    |
# |    value_loss         | 50.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.16     |
# |    ep_rew_mean        | 7.16     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 6200     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.662    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.192   |
# |    std                | 0.869    |
# |    value_loss         | 2.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.87     |
# |    ep_rew_mean        | 5.87     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 6300     |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.639    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.484    |
# |    std                | 0.856    |
# |    value_loss         | 0.876    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 8.8      |
# |    ep_rew_mean        | 7.8      |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 6400     |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.291    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 1.68     |
# |    std                | 0.858    |
# |    value_loss         | 4.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.8     |
# |    ep_rew_mean        | 9.78     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 6500     |
# |    time_elapsed       | 132      |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.883    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -2.26    |
# |    std                | 0.872    |
# |    value_loss         | 5.89     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.5     |
# |    ep_rew_mean        | 12.5     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 6600     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.63     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.442   |
# |    std                | 0.876    |
# |    value_loss         | 0.601    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.3     |
# |    ep_rew_mean        | 16.3     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 6700     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.359    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 1.47     |
# |    std                | 0.885    |
# |    value_loss         | 2.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.1     |
# |    ep_rew_mean        | 20.1     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 6800     |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.579    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.856   |
# |    std                | 0.883    |
# |    value_loss         | 0.643    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.9     |
# |    ep_rew_mean        | 23.9     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 6900     |
# |    time_elapsed       | 139      |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.554    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 1.34     |
# |    std                | 0.888    |
# |    value_loss         | 0.805    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.9     |
# |    ep_rew_mean        | 27.9     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 7000     |
# |    time_elapsed       | 141      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.375    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.535    |
# |    std                | 0.872    |
# |    value_loss         | 0.395    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33.4     |
# |    ep_rew_mean        | 32.4     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 7100     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.256    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -79.3    |
# ...
# |    total_timesteps    | 88500     |
# | train/                |           |
# |    entropy_loss       | -0.127    |
# |    explained_variance | -30.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17699     |
# |    policy_loss        | -0.000252 |
# |    std                | 0.275     |
# |    value_loss         | 1.07e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 173      |
# |    ep_rew_mean        | 172      |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 17800    |
# |    time_elapsed       | 373      |
# |    total_timesteps    | 89000    |
# | train/                |          |
# |    entropy_loss       | -0.121   |
# |    explained_variance | -229     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | -9.5e-05 |
# |    std                | 0.273    |
# |    value_loss         | 1.29e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 183      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 17900    |
# |    time_elapsed       | 375      |
# |    total_timesteps    | 89500    |
# | train/                |          |
# |    entropy_loss       | -0.116   |
# |    explained_variance | -2.51    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | 0.00017  |
# |    std                | 0.272    |
# |    value_loss         | 3.51e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 183      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 18000    |
# |    time_elapsed       | 377      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.104   |
# |    explained_variance | -56.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 0.000272 |
# |    std                | 0.269    |
# |    value_loss         | 1.63e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 193       |
# |    ep_rew_mean        | 192       |
# | time/                 |           |
# |    fps                | 238       |
# |    iterations         | 18100     |
# |    time_elapsed       | 379       |
# |    total_timesteps    | 90500     |
# | train/                |           |
# |    entropy_loss       | -0.094    |
# |    explained_variance | -5.24     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18099     |
# |    policy_loss        | -0.000242 |
# |    std                | 0.266     |
# |    value_loss         | 5.71e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 193       |
# |    ep_rew_mean        | 192       |
# | time/                 |           |
# |    fps                | 238       |
# |    iterations         | 18200     |
# |    time_elapsed       | 382       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -0.0704   |
# |    explained_variance | -69.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | -0.000466 |
# |    std                | 0.26      |
# |    value_loss         | 1.45e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 203       |
# |    ep_rew_mean        | 202       |
# | time/                 |           |
# |    fps                | 238       |
# |    iterations         | 18300     |
# |    time_elapsed       | 384       |
# |    total_timesteps    | 91500     |
# | train/                |           |
# |    entropy_loss       | -0.049    |
# |    explained_variance | -9.37     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18299     |
# |    policy_loss        | -7.44e-05 |
# |    std                | 0.254     |
# |    value_loss         | 1e-06     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 203       |
# |    ep_rew_mean        | 202       |
# | time/                 |           |
# |    fps                | 237       |
# |    iterations         | 18400     |
# |    time_elapsed       | 386       |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -0.0402   |
# |    explained_variance | -0.876    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18399     |
# |    policy_loss        | -0.000664 |
# |    std                | 0.252     |
# |    value_loss         | 5.89e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 213       |
# |    ep_rew_mean        | 212       |
# | time/                 |           |
# |    fps                | 237       |
# |    iterations         | 18500     |
# |    time_elapsed       | 388       |
# |    total_timesteps    | 92500     |
# | train/                |           |
# |    entropy_loss       | -0.02     |
# |    explained_variance | -2.14e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18499     |
# |    policy_loss        | 0.00325   |
# |    std                | 0.247     |
# |    value_loss         | 0.0157    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | 214      |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 18600    |
# |    time_elapsed       | 390      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | 0.000757 |
# |    explained_variance | -120     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 0.000978 |
# |    std                | 0.242    |
# |    value_loss         | 2.88e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | 214      |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 18700    |
# |    time_elapsed       | 392      |
# |    total_timesteps    | 93500    |
# | train/                |          |
# |    entropy_loss       | 0.0139   |
# |    explained_variance | -43.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | -0.00236 |
# |    std                | 0.239    |
# |    value_loss         | 5.84e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 224      |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 18800    |
# |    time_elapsed       | 395      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | 0.0226   |
# |    explained_variance | -10.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 1.12e-05 |
# |    std                | 0.237    |
# |    value_loss         | 3.79e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 225       |
# |    ep_rew_mean        | 224       |
# | time/                 |           |
# |    fps                | 238       |
# |    iterations         | 18900     |
# |    time_elapsed       | 397       |
# |    total_timesteps    | 94500     |
# | train/                |           |
# |    entropy_loss       | 0.0353    |
# |    explained_variance | -17.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18899     |
# |    policy_loss        | -0.000309 |
# |    std                | 0.234     |
# |    value_loss         | 2.31e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | 234      |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 19000    |
# |    time_elapsed       | 399      |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | 0.0472   |
# |    explained_variance | -19.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | -0.00138 |
# |    std                | 0.231    |
# |    value_loss         | 2.61e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 235       |
# |    ep_rew_mean        | 234       |
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 19100     |
# |    time_elapsed       | 402       |
# |    total_timesteps    | 95500     |
# | train/                |           |
# |    entropy_loss       | 0.0556    |
# |    explained_variance | -67.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19099     |
# |    policy_loss        | -0.000358 |
# |    std                | 0.229     |
# |    value_loss         | 1.6e-06   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 245       |
# |    ep_rew_mean        | 244       |
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 19200     |
# |    time_elapsed       | 406       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | 0.0485    |
# |    explained_variance | -19.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19199     |
# |    policy_loss        | -8.97e-05 |
# |    std                | 0.231     |
# |    value_loss         | 3.39e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 245      |
# |    ep_rew_mean        | 244      |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19300    |
# |    time_elapsed       | 408      |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | 0.0565   |
# |    explained_variance | -318     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | 4.97e-05 |
# |    std                | 0.229    |
# |    value_loss         | 3.55e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 255       |
# |    ep_rew_mean        | 254       |
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 19400     |
# |    time_elapsed       | 410       |
# |    total_timesteps    | 97000     |
# | train/                |           |
# |    entropy_loss       | 0.07      |
# |    explained_variance | -2.35     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19399     |
# |    policy_loss        | -1.04e-05 |
# |    std                | 0.226     |
# |    value_loss         | 3.24e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 255      |
# |    ep_rew_mean        | 254      |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19500    |
# |    time_elapsed       | 412      |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | 0.0639   |
# |    explained_variance | -84.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | 0.000141 |
# |    std                | 0.227    |
# |    value_loss         | 2.92e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 265      |
# |    ep_rew_mean        | 264      |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 19600    |
# |    time_elapsed       | 415      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | 0.0695   |
# |    explained_variance | -7.43    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | -0.00016 |
# |    std                | 0.226    |
# |    value_loss         | 6.9e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 265       |
# |    ep_rew_mean        | 264       |
# | time/                 |           |
# |    fps                | 235       |
# |    iterations         | 19700     |
# |    time_elapsed       | 417       |
# |    total_timesteps    | 98500     |
# | train/                |           |
# |    entropy_loss       | 0.0868    |
# |    explained_variance | -90.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19699     |
# |    policy_loss        | -6.33e-05 |
# |    std                | 0.222     |
# |    value_loss         | 1.71e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 275       |
# |    ep_rew_mean        | 274       |
# | time/                 |           |
# |    fps                | 234       |
# |    iterations         | 19800     |
# |    time_elapsed       | 422       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | 0.0947    |
# |    explained_variance | -7.05     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -0.000755 |
# |    std                | 0.22      |
# |    value_loss         | 4.78e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 275      |
# |    ep_rew_mean        | 274      |
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 19900    |
# |    time_elapsed       | 427      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | 0.107    |
# |    explained_variance | -47      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | -0.00097 |
# |    std                | 0.217    |
# |    value_loss         | 9.31e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 285       |
# |    ep_rew_mean        | 284       |
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 20000     |
# |    time_elapsed       | 431       |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | 0.129     |
# |    explained_variance | -6.36     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19999     |
# |    policy_loss        | -0.000119 |
# |    std                | 0.213     |
# |    value_loss         | 3.47e-07  |
# -------------------------------------
# Training complete. Model saved. Training took 431.25 seconds.

# %%
trainer.plot_rewards()
model = A2C.load("a2c_ip_model")
trainer.generate_video(model,video_filename='a2c_ip_video.mp4')
# Out:
# Total reward: 1000
#         <video width=600 controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# ## Ejercicio práctico 3

# %% [markdown]
# Reduzca la tasa de aprendizaje y aumente el n_steps para obtener un aprendizaje más estable para el modelo A2C

# %%
# Ejercicio practico 3: A2C en InvertedPendulum con hiperparametros ajustados
# - learning_rate reducido (default 7e-4 -> 3e-4) para actualizaciones suaves
# - n_steps aumentado (default 5 -> 32) para estimaciones de ventaja con
#   menor varianza
def create_model(env):
    return A2C(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        n_steps=32,
        gamma=0.99,
        gae_lambda=0.95,
        ent_coef=0.0,
        vf_coef=0.5,
        max_grad_norm=0.5,
        verbose=1,
        device="cuda" if torch.cuda.is_available() else "cpu",
    )

trainer = IPTrainer(model_fn=create_model, total_timesteps=200_000)
trainer.train(save_path="a2c_ip_model1")
# Out:
# Using cuda device
# GPU available? True
# Using device: NVIDIA GeForce RTX 4060 Laptop GPU
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.1     |
# |    ep_rew_mean        | 19.1     |
# | time/                 |          |
# |    fps                | 206      |
# |    iterations         | 100      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 3200     |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.153    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 99       |
# |    policy_loss        | 10.9     |
# |    std                | 0.986    |
# |    value_loss         | 74       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 32.3     |
# |    ep_rew_mean        | 31.3     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 200      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 6400     |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.026    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.16     |
# |    std                | 0.979    |
# |    value_loss         | 23.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | 46.1     |
# | time/                 |          |
# |    fps                | 231      |
# |    iterations         | 300      |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 9600     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.276    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 299      |
# |    policy_loss        | 2.8      |
# |    std                | 0.972    |
# |    value_loss         | 28.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 64.9     |
# |    ep_rew_mean        | 63.9     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 400      |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 12800    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.182   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 399      |
# |    policy_loss        | 10.4     |
# |    std                | 0.957    |
# |    value_loss         | 84.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 70.8     |
# |    ep_rew_mean        | 69.8     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 500      |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.0532  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0914  |
# |    std                | 0.956    |
# |    value_loss         | 53.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.4     |
# |    ep_rew_mean        | 73.4     |
# | time/                 |          |
# |    fps                | 281      |
# |    iterations         | 600      |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 19200    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.0308  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 599      |
# |    policy_loss        | 4.87     |
# |    std                | 0.952    |
# |    value_loss         | 88.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.1     |
# |    ep_rew_mean        | 78.1     |
# | time/                 |          |
# |    fps                | 295      |
# |    iterations         | 700      |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 22400    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.104   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 699      |
# |    policy_loss        | 8.49     |
# |    std                | 0.949    |
# |    value_loss         | 72.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.7     |
# |    ep_rew_mean        | 87.7     |
# | time/                 |          |
# |    fps                | 298      |
# |    iterations         | 800      |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 25600    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.000847 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 799      |
# |    policy_loss        | -6.09    |
# |    std                | 0.948    |
# |    value_loss         | 86.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.8     |
# |    ep_rew_mean        | 92.8     |
# | time/                 |          |
# |    fps                | 305      |
# |    iterations         | 900      |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 28800    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.114    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 899      |
# |    policy_loss        | 9.9      |
# |    std                | 0.951    |
# |    value_loss         | 60.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 102      |
# |    ep_rew_mean        | 101      |
# | time/                 |          |
# |    fps                | 310      |
# |    iterations         | 1000     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.0504   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 999      |
# |    policy_loss        | 8.72     |
# |    std                | 0.949    |
# |    value_loss         | 59.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.7     |
# |    ep_rew_mean        | 98.7     |
# | time/                 |          |
# |    fps                | 313      |
# |    iterations         | 1100     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 35200    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.0602   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1099     |
# |    policy_loss        | 8.84     |
# |    std                | 0.951    |
# |    value_loss         | 57.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.1     |
# |    ep_rew_mean        | 92.1     |
# | time/                 |          |
# |    fps                | 319      |
# |    iterations         | 1200     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 38400    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | -0.0112  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1199     |
# |    policy_loss        | 9.11     |
# |    std                | 0.947    |
# |    value_loss         | 57.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.9     |
# |    ep_rew_mean        | 87.9     |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 1300     |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 41600    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.469    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1299     |
# |    policy_loss        | -4.08    |
# |    std                | 0.942    |
# |    value_loss         | 84.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.7     |
# |    ep_rew_mean        | 90.7     |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 1400     |
# |    time_elapsed       | 139      |
# |    total_timesteps    | 44800    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | -0.227   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1399     |
# |    policy_loss        | 9.24     |
# |    std                | 0.943    |
# |    value_loss         | 58       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 102      |
# |    ep_rew_mean        | 101      |
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 1500     |
# |    time_elapsed       | 148      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.00502  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1499     |
# |    policy_loss        | 9.13     |
# |    std                | 0.94     |
# |    value_loss         | 51.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 114      |
# |    ep_rew_mean        | 113      |
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 1600     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 51200    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.792    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1599     |
# |    policy_loss        | 9.08     |
# |    std                | 0.936    |
# |    value_loss         | 47.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 124      |
# |    ep_rew_mean        | 123      |
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 1700     |
# |    time_elapsed       | 164      |
# |    total_timesteps    | 54400    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.0483   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1699     |
# |    policy_loss        | 8.53     |
# |    std                | 0.931    |
# |    value_loss         | 45.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | 136      |
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 1800     |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 57600    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.562    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1799     |
# |    policy_loss        | 9.06     |
# |    std                | 0.928    |
# |    value_loss         | 41       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 145      |
# |    ep_rew_mean        | 144      |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 1900     |
# |    time_elapsed       | 181      |
# |    total_timesteps    | 60800    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.0259   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1899     |
# |    policy_loss        | 7.63     |
# |    std                | 0.929    |
# |    value_loss         | 42       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 162      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 2000     |
# |    time_elapsed       | 188      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.0575  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1999     |
# |    policy_loss        | 7.62     |
# |    std                | 0.924    |
# |    value_loss         | 40.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 169      |
# |    ep_rew_mean        | 168      |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 2100     |
# |    time_elapsed       | 198      |
# |    total_timesteps    | 67200    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.00634  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2099     |
# |    policy_loss        | -20.6    |
# |    std                | 0.923    |
# |    value_loss         | 326      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 168      |
# |    ep_rew_mean        | 167      |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 2200     |
# |    time_elapsed       | 209      |
# |    total_timesteps    | 70400    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.00789  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2199     |
# |    policy_loss        | 6.8      |
# |    std                | 0.917    |
# |    value_loss         | 36.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 180      |
# |    ep_rew_mean        | 179      |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 2300     |
# |    time_elapsed       | 219      |
# |    total_timesteps    | 73600    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.0226   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2299     |
# |    policy_loss        | 7.17     |
# |    std                | 0.918    |
# |    value_loss         | 34.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 184      |
# |    ep_rew_mean        | 183      |
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 2400     |
# |    time_elapsed       | 233      |
# |    total_timesteps    | 76800    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.00671  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2399     |
# |    policy_loss        | -20.7    |
# |    std                | 0.911    |
# |    value_loss         | 419      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 194      |
# |    ep_rew_mean        | 193      |
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 2500     |
# |    time_elapsed       | 244      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 0.00314  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2499     |
# |    policy_loss        | 6.55     |
# |    std                | 0.908    |
# |    value_loss         | 30.5     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 213       |
# |    ep_rew_mean        | 212       |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 2600      |
# |    time_elapsed       | 254       |
# |    total_timesteps    | 83200     |
# | train/                |           |
# |    entropy_loss       | -1.32     |
# |    explained_variance | -0.000371 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2599      |
# |    policy_loss        | 8         |
# |    std                | 0.904     |
# |    value_loss         | 28.7      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 230      |
# |    ep_rew_mean        | 229      |
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 2700     |
# |    time_elapsed       | 266      |
# |    total_timesteps    | 86400    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | -0.00125 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2699     |
# |    policy_loss        | 5.96     |
# |    std                | 0.9      |
# |    value_loss         | 26.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 244      |
# |    ep_rew_mean        | 243      |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 2800     |
# |    time_elapsed       | 275      |
# |    total_timesteps    | 89600    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | -0.00313 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2799     |
# |    policy_loss        | 5.85     |
# |    std                | 0.901    |
# |    value_loss         | 25       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 259      |
# |    ep_rew_mean        | 258      |
# | time/                 |          |
# |    fps                | 326      |
# |    iterations         | 2900     |
# |    time_elapsed       | 283      |
# |    total_timesteps    | 92800    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.0118   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2899     |
# |    policy_loss        | 8.26     |
# |    std                | 0.9      |
# |    value_loss         | 23       |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 267       |
# |    ep_rew_mean        | 267       |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 3000      |
# |    time_elapsed       | 293       |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -1.31     |
# |    explained_variance | -0.000649 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2999      |
# |    policy_loss        | 5.57      |
# |    std                | 0.897     |
# |    value_loss         | 21.9      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 291      |
# |    ep_rew_mean        | 290      |
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 3100     |
# |    time_elapsed       | 301      |
# |    total_timesteps    | 99200    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.000516 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3099     |
# |    policy_loss        | 5.28     |
# |    std                | 0.897    |
# |    value_loss         | 20.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 300       |
# |    ep_rew_mean        | 299       |
# | time/                 |           |
# |    fps                | 330       |
# |    iterations         | 3200      |
# |    time_elapsed       | 309       |
# |    total_timesteps    | 102400    |
# | train/                |           |
# |    entropy_loss       | -1.31     |
# |    explained_variance | -0.000913 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3199      |
# |    policy_loss        | 4.83      |
# |    std                | 0.898     |
# |    value_loss         | 18.8      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 324       |
# |    ep_rew_mean        | 324       |
# | time/                 |           |
# |    fps                | 332       |
# |    iterations         | 3300      |
# |    time_elapsed       | 317       |
# |    total_timesteps    | 105600    |
# | train/                |           |
# |    entropy_loss       | -1.32     |
# |    explained_variance | -0.000711 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3299      |
# |    policy_loss        | 4.33      |
# |    std                | 0.901     |
# |    value_loss         | 17.2      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 347      |
# |    ep_rew_mean        | 346      |
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 3400     |
# |    time_elapsed       | 324      |
# |    total_timesteps    | 108800   |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.00112  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3399     |
# |    policy_loss        | 4.45     |
# |    std                | 0.897    |
# |    value_loss         | 15.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 362      |
# |    ep_rew_mean        | 361      |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 3500     |
# |    time_elapsed       | 332      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | -0.00428 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3499     |
# |    policy_loss        | 4.02     |
# |    std                | 0.897    |
# |    value_loss         | 14.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 376      |
# |    ep_rew_mean        | 375      |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 3600     |
# |    time_elapsed       | 339      |
# |    total_timesteps    | 115200   |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.0017  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3599     |
# |    policy_loss        | 4.09     |
# |    std                | 0.891    |
# |    value_loss         | 13       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 373      |
# |    ep_rew_mean        | 372      |
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 3700     |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 118400   |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.0659   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3699     |
# |    policy_loss        | 4.43     |
# |    std                | 0.886    |
# |    value_loss         | 11.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 358      |
# |    ep_rew_mean        | 357      |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 3800     |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 121600   |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | -0.0008  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3799     |
# |    policy_loss        | 4.58     |
# |    std                | 0.883    |
# |    value_loss         | 10.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 350      |
# |    ep_rew_mean        | 349      |
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 3900     |
# |    time_elapsed       | 360      |
# |    total_timesteps    | 124800   |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.00289  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3899     |
# |    policy_loss        | 3.74     |
# |    std                | 0.881    |
# |    value_loss         | 9.65     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 364      |
# |    ep_rew_mean        | 363      |
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 4000     |
# |    time_elapsed       | 368      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.000772 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3999     |
# |    policy_loss        | 3.26     |
# |    std                | 0.876    |
# |    value_loss         | 8.47     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 390      |
# |    ep_rew_mean        | 389      |
# | time/                 |          |
# |    fps                | 348      |
# |    iterations         | 4100     |
# |    time_elapsed       | 376      |
# |    total_timesteps    | 131200   |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | -0.00221 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4099     |
# |    policy_loss        | 2.98     |
# |    std                | 0.869    |
# |    value_loss         | 7.36     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 411      |
# |    ep_rew_mean        | 410      |
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 4200     |
# |    time_elapsed       | 384      |
# |    total_timesteps    | 134400   |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.0132   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4199     |
# |    policy_loss        | 2.75     |
# |    std                | 0.87     |
# |    value_loss         | 6.36     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 434      |
# |    ep_rew_mean        | 433      |
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 4300     |
# |    time_elapsed       | 392      |
# |    total_timesteps    | 137600   |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.00364  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4299     |
# |    policy_loss        | -2.14    |
# |    std                | 0.865    |
# |    value_loss         | 358      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 450      |
# |    ep_rew_mean        | 449      |
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 4400     |
# |    time_elapsed       | 402      |
# |    total_timesteps    | 140800   |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.00852  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4399     |
# |    policy_loss        | 2.17     |
# |    std                | 0.861    |
# |    value_loss         | 4.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 468      |
# |    ep_rew_mean        | 467      |
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 4500     |
# |    time_elapsed       | 415      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.000131 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4499     |
# |    policy_loss        | 2.15     |
# |    std                | 0.857    |
# |    value_loss         | 3.74     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 484       |
# |    ep_rew_mean        | 483       |
# | time/                 |           |
# |    fps                | 348       |
# |    iterations         | 4600      |
# |    time_elapsed       | 422       |
# |    total_timesteps    | 147200    |
# | train/                |           |
# |    entropy_loss       | -1.27     |
# |    explained_variance | -0.000812 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 4599      |
# |    policy_loss        | 2.14      |
# |    std                | 0.859     |
# |    value_loss         | 2.99      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 506      |
# |    ep_rew_mean        | 505      |
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 4700     |
# |    time_elapsed       | 429      |
# |    total_timesteps    | 150400   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | -0.00221 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4699     |
# |    policy_loss        | 2.01     |
# |    std                | 0.856    |
# |    value_loss         | 2.33     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | 526      |
# | time/                 |          |
# |    fps                | 351      |
# |    iterations         | 4800     |
# |    time_elapsed       | 437      |
# |    total_timesteps    | 153600   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.00064  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4799     |
# |    policy_loss        | 1.6      |
# |    std                | 0.854    |
# |    value_loss         | 1.76     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 556       |
# |    ep_rew_mean        | 555       |
# | time/                 |           |
# |    fps                | 352       |
# |    iterations         | 4900      |
# |    time_elapsed       | 444       |
# |    total_timesteps    | 156800    |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -0.000122 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 4899      |
# |    policy_loss        | 1.19      |
# |    std                | 0.852     |
# |    value_loss         | 1.26      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 570       |
# |    ep_rew_mean        | 570       |
# | time/                 |           |
# |    fps                | 354       |
# |    iterations         | 5000      |
# |    time_elapsed       | 451       |
# |    total_timesteps    | 160000    |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -0.000786 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 4999      |
# |    policy_loss        | 1.18      |
# |    std                | 0.851     |
# |    value_loss         | 0.845     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 576      |
# |    ep_rew_mean        | 576      |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 5100     |
# |    time_elapsed       | 461      |
# |    total_timesteps    | 163200   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | -0.00106 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.893    |
# |    std                | 0.853    |
# |    value_loss         | 0.512    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 585      |
# |    ep_rew_mean        | 585      |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 5200     |
# |    time_elapsed       | 471      |
# |    total_timesteps    | 166400   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.0011   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.644    |
# |    std                | 0.85     |
# |    value_loss         | 0.266    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 586      |
# |    ep_rew_mean        | 585      |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 5300     |
# |    time_elapsed       | 481      |
# |    total_timesteps    | 169600   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.0428   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.463    |
# |    std                | 0.854    |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 593      |
# |    ep_rew_mean        | 592      |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 5400     |
# |    time_elapsed       | 490      |
# |    total_timesteps    | 172800   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.00537  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.172    |
# |    std                | 0.853    |
# |    value_loss         | 0.0209   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 615      |
# |    ep_rew_mean        | 614      |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 5500     |
# |    time_elapsed       | 498      |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.034    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0114   |
# |    std                | 0.849    |
# |    value_loss         | 7.53e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 633       |
# |    ep_rew_mean        | 633       |
# | time/                 |           |
# |    fps                | 353       |
# |    iterations         | 5600      |
# |    time_elapsed       | 507       |
# |    total_timesteps    | 179200    |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -0.693    |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5599      |
# |    policy_loss        | -1.72e-05 |
# |    std                | 0.849     |
# |    value_loss         | 9.64e-09  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 655      |
# |    ep_rew_mean        | 654      |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 5700     |
# |    time_elapsed       | 515      |
# |    total_timesteps    | 182400   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | -1.19    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5699     |
# |    policy_loss        | -6.9e-05 |
# |    std                | 0.849    |
# |    value_loss         | 6.14e-09 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 676       |
# |    ep_rew_mean        | 675       |
# | time/                 |           |
# |    fps                | 353       |
# |    iterations         | 5800      |
# |    time_elapsed       | 524       |
# |    total_timesteps    | 185600    |
# | train/                |           |
# |    entropy_loss       | -1.26     |
# |    explained_variance | -34.4     |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5799      |
# |    policy_loss        | -4.63e-06 |
# |    std                | 0.849     |
# |    value_loss         | 1.14e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 699      |
# |    ep_rew_mean        | 699      |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 5900     |
# |    time_elapsed       | 533      |
# |    total_timesteps    | 188800   |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | -0.0435  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00589  |
# |    std                | 0.845    |
# |    value_loss         | 2.72e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 722      |
# |    ep_rew_mean        | 721      |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 6000     |
# |    time_elapsed       | 541      |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | -4.07    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.00067  |
# |    std                | 0.845    |
# |    value_loss         | 7.7e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 745       |
# |    ep_rew_mean        | 745       |
# | time/                 |           |
# |    fps                | 354       |
# |    iterations         | 6100      |
# |    time_elapsed       | 550       |
# |    total_timesteps    | 195200    |
# | train/                |           |
# |    entropy_loss       | -1.25     |
# |    explained_variance | -0.893    |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 6099      |
# |    policy_loss        | -8.33e-05 |
# |    std                | 0.844     |
# |    value_loss         | 4.88e-09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 763       |
# |    ep_rew_mean        | 762       |
# | time/                 |           |
# |    fps                | 351       |
# |    iterations         | 6200      |
# |    time_elapsed       | 563       |
# |    total_timesteps    | 198400    |
# | train/                |           |
# |    entropy_loss       | -1.25     |
# |    explained_variance | -18.5     |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 6199      |
# |    policy_loss        | -6.71e-05 |
# |    std                | 0.842     |
# |    value_loss         | 5.01e-09  |
# -------------------------------------
# Training complete. Model saved. Training took 572.61 seconds.

# %%
trainer.plot_rewards()
model = A2C.load("a2c_ip_model1")
trainer.generate_video(model, video_filename='a2c_ip_video1.mp4')
# Out:
# Total reward: 1000
#         <video width=600 controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# ## Ejercicio Practico 4

# %% [markdown]
# Realice el entrenamiento de un modelo A2C para el ambiente de Inverted Double Pendulum (tenga en cuenta que A2C corre mejor en GPU)

# %%
# Ejercicio practico 4: A2C en InvertedDoublePendulum
# A2C aprovecha mejor la GPU; aumentamos timesteps porque IDP es mas dificil.
def create_model(env):
    return A2C(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        n_steps=32,
        gamma=0.99,
        gae_lambda=0.95,
        ent_coef=0.0,
        vf_coef=0.5,
        max_grad_norm=0.5,
        verbose=1,
        device="cuda" if torch.cuda.is_available() else "cpu",
    )

trainer = IDPTrainer(model_fn=create_model, total_timesteps=300_000)
trainer.train(save_path="a2c_idp_model")
# Out:
# Using cuda device
# GPU available? True
# Using device: NVIDIA GeForce RTX 4060 Laptop GPU
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 9.73     |
# |    ep_rew_mean        | 79.3     |
# | time/                 |          |
# |    fps                | 71       |
# |    iterations         | 100      |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 3200     |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.051    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 99       |
# |    policy_loss        | 51.6     |
# |    std                | 0.98     |
# |    value_loss         | 2.45e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 9.18     |
# |    ep_rew_mean        | 74.2     |
# | time/                 |          |
# |    fps                | 74       |
# |    iterations         | 200      |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 6400     |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.0585   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 199      |
# |    policy_loss        | 38.1     |
# |    std                | 0.982    |
# |    value_loss         | 1.12e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.4     |
# |    ep_rew_mean        | 86.1     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 300      |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 9600     |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.0263   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 299      |
# |    policy_loss        | 40.2     |
# |    std                | 0.977    |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 9.75     |
# |    ep_rew_mean        | 79.6     |
# | time/                 |          |
# |    fps                | 119      |
# |    iterations         | 400      |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 12800    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.00291  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 399      |
# |    policy_loss        | 28.3     |
# |    std                | 0.973    |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.6     |
# |    ep_rew_mean        | 87.3     |
# | time/                 |          |
# |    fps                | 138      |
# |    iterations         | 500      |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.0708   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 499      |
# |    policy_loss        | 29.5     |
# |    std                | 0.967    |
# |    value_loss         | 989      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.2     |
# |    ep_rew_mean        | 83.7     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 600      |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 19200    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0438   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 599      |
# |    policy_loss        | 29       |
# |    std                | 0.964    |
# |    value_loss         | 900      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.7     |
# |    ep_rew_mean        | 88.2     |
# | time/                 |          |
# |    fps                | 167      |
# |    iterations         | 700      |
# |    time_elapsed       | 134      |
# |    total_timesteps    | 22400    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0452   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 699      |
# |    policy_loss        | 21       |
# |    std                | 0.963    |
# |    value_loss         | 882      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.8     |
# |    ep_rew_mean        | 88.9     |
# | time/                 |          |
# |    fps                | 178      |
# |    iterations         | 800      |
# |    time_elapsed       | 143      |
# |    total_timesteps    | 25600    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.114    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 799      |
# |    policy_loss        | 31.3     |
# |    std                | 0.957    |
# |    value_loss         | 1.36e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 10.9     |
# |    ep_rew_mean        | 90.7     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 900      |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 28800    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.249    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 899      |
# |    policy_loss        | 17.8     |
# |    std                | 0.958    |
# |    value_loss         | 483      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 11.8     |
# |    ep_rew_mean        | 99       |
# | time/                 |          |
# |    fps                | 197      |
# |    iterations         | 1000     |
# |    time_elapsed       | 161      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.218    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 999      |
# |    policy_loss        | 32.2     |
# |    std                | 0.954    |
# |    value_loss         | 1.2e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 11.7     |
# |    ep_rew_mean        | 97.6     |
# | time/                 |          |
# |    fps                | 206      |
# |    iterations         | 1100     |
# |    time_elapsed       | 170      |
# |    total_timesteps    | 35200    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.148    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1099     |
# |    policy_loss        | 40.2     |
# |    std                | 0.954    |
# |    value_loss         | 2.17e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 11.9     |
# |    ep_rew_mean        | 99.5     |
# | time/                 |          |
# |    fps                | 213      |
# |    iterations         | 1200     |
# |    time_elapsed       | 180      |
# |    total_timesteps    | 38400    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.437    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1199     |
# |    policy_loss        | 19.1     |
# |    std                | 0.948    |
# |    value_loss         | 478      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 12.3     |
# |    ep_rew_mean        | 103      |
# | time/                 |          |
# |    fps                | 219      |
# |    iterations         | 1300     |
# |    time_elapsed       | 189      |
# |    total_timesteps    | 41600    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.0822   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1299     |
# |    policy_loss        | 59.7     |
# |    std                | 0.938    |
# |    value_loss         | 4.23e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 12.8     |
# |    ep_rew_mean        | 107      |
# | time/                 |          |
# |    fps                | 224      |
# |    iterations         | 1400     |
# |    time_elapsed       | 199      |
# |    total_timesteps    | 44800    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.2      |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1399     |
# |    policy_loss        | 29.1     |
# |    std                | 0.934    |
# |    value_loss         | 1.46e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.2     |
# |    ep_rew_mean        | 112      |
# | time/                 |          |
# |    fps                | 231      |
# |    iterations         | 1500     |
# |    time_elapsed       | 207      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.307    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1499     |
# |    policy_loss        | 10.2     |
# |    std                | 0.923    |
# |    value_loss         | 504      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.8     |
# |    ep_rew_mean        | 116      |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 1600     |
# |    time_elapsed       | 214      |
# |    total_timesteps    | 51200    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.225    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1599     |
# |    policy_loss        | 27.8     |
# |    std                | 0.915    |
# |    value_loss         | 1.13e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.3     |
# |    ep_rew_mean        | 112      |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 1700     |
# |    time_elapsed       | 222      |
# |    total_timesteps    | 54400    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.336    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1699     |
# |    policy_loss        | 42.6     |
# |    std                | 0.911    |
# |    value_loss         | 2.9e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14       |
# |    ep_rew_mean        | 119      |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 1800     |
# |    time_elapsed       | 229      |
# |    total_timesteps    | 57600    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 0.401    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1799     |
# |    policy_loss        | 18.2     |
# |    std                | 0.905    |
# |    value_loss         | 893      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.3     |
# |    ep_rew_mean        | 122      |
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 1900     |
# |    time_elapsed       | 236      |
# |    total_timesteps    | 60800    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.0263   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1899     |
# |    policy_loss        | 31.8     |
# |    std                | 0.899    |
# |    value_loss         | 1.91e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.3     |
# |    ep_rew_mean        | 130      |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 2000     |
# |    time_elapsed       | 244      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.251    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1999     |
# |    policy_loss        | 20.4     |
# |    std                | 0.893    |
# |    value_loss         | 1.45e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.8     |
# |    ep_rew_mean        | 135      |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 2100     |
# |    time_elapsed       | 251      |
# |    total_timesteps    | 67200    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.278    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2099     |
# |    policy_loss        | 47.2     |
# |    std                | 0.887    |
# |    value_loss         | 1.84e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.7     |
# |    ep_rew_mean        | 134      |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2200     |
# |    time_elapsed       | 258      |
# |    total_timesteps    | 70400    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.125    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2199     |
# |    policy_loss        | 47.3     |
# |    std                | 0.881    |
# |    value_loss         | 3.06e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.6     |
# |    ep_rew_mean        | 133      |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 2300     |
# |    time_elapsed       | 265      |
# |    total_timesteps    | 73600    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.325    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2299     |
# |    policy_loss        | 34.7     |
# |    std                | 0.876    |
# |    value_loss         | 1.79e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.2     |
# |    ep_rew_mean        | 138      |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 2400     |
# |    time_elapsed       | 273      |
# |    total_timesteps    | 76800    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.314    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2399     |
# |    policy_loss        | 38.7     |
# |    std                | 0.868    |
# |    value_loss         | 2.08e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.4     |
# |    ep_rew_mean        | 131      |
# | time/                 |          |
# |    fps                | 285      |
# |    iterations         | 2500     |
# |    time_elapsed       | 280      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.122    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2499     |
# |    policy_loss        | 20.5     |
# |    std                | 0.861    |
# |    value_loss         | 1.61e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.6     |
# |    ep_rew_mean        | 152      |
# | time/                 |          |
# |    fps                | 288      |
# |    iterations         | 2600     |
# |    time_elapsed       | 287      |
# |    total_timesteps    | 83200    |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.547    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2599     |
# |    policy_loss        | -5.77    |
# |    std                | 0.854    |
# |    value_loss         | 320      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.4     |
# |    ep_rew_mean        | 141      |
# | time/                 |          |
# |    fps                | 292      |
# |    iterations         | 2700     |
# |    time_elapsed       | 295      |
# |    total_timesteps    | 86400    |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 0.216    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2699     |
# |    policy_loss        | 56.1     |
# |    std                | 0.845    |
# |    value_loss         | 2.36e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.2     |
# |    ep_rew_mean        | 167      |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 2800     |
# |    time_elapsed       | 302      |
# |    total_timesteps    | 89600    |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.102    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2799     |
# |    policy_loss        | 32.6     |
# |    std                | 0.836    |
# |    value_loss         | 2.73e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.5     |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 299      |
# |    iterations         | 2900     |
# |    time_elapsed       | 309      |
# |    total_timesteps    | 92800    |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.49     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2899     |
# |    policy_loss        | 22.8     |
# |    std                | 0.834    |
# |    value_loss         | 1.01e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.7     |
# |    ep_rew_mean        | 152      |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 3000     |
# |    time_elapsed       | 317      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | 0.514    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2999     |
# |    policy_loss        | -7.99    |
# |    std                | 0.831    |
# |    value_loss         | 474      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.6     |
# |    ep_rew_mean        | 170      |
# | time/                 |          |
# |    fps                | 305      |
# |    iterations         | 3100     |
# |    time_elapsed       | 324      |
# |    total_timesteps    | 99200    |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | 0.346    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3099     |
# |    policy_loss        | 20.2     |
# |    std                | 0.825    |
# |    value_loss         | 1.44e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.1     |
# |    ep_rew_mean        | 156      |
# | time/                 |          |
# |    fps                | 308      |
# |    iterations         | 3200     |
# |    time_elapsed       | 331      |
# |    total_timesteps    | 102400   |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | 0.385    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3199     |
# |    policy_loss        | 8.36     |
# |    std                | 0.82     |
# |    value_loss         | 744      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.2     |
# |    ep_rew_mean        | 148      |
# | time/                 |          |
# |    fps                | 311      |
# |    iterations         | 3300     |
# |    time_elapsed       | 339      |
# |    total_timesteps    | 105600   |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | 0.575    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3299     |
# |    policy_loss        | 8.2      |
# |    std                | 0.818    |
# |    value_loss         | 560      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.9     |
# |    ep_rew_mean        | 173      |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 3400     |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 108800   |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.419    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3399     |
# |    policy_loss        | 39.2     |
# |    std                | 0.814    |
# |    value_loss         | 2.71e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.4     |
# |    ep_rew_mean        | 178      |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 3500     |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.515    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3499     |
# |    policy_loss        | 7.45     |
# |    std                | 0.81     |
# |    value_loss         | 616      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.4     |
# |    ep_rew_mean        | 159      |
# | time/                 |          |
# |    fps                | 319      |
# |    iterations         | 3600     |
# |    time_elapsed       | 361      |
# |    total_timesteps    | 115200   |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.417    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3599     |
# |    policy_loss        | 21       |
# |    std                | 0.808    |
# |    value_loss         | 1.87e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.2     |
# |    ep_rew_mean        | 185      |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 3700     |
# |    time_elapsed       | 368      |
# |    total_timesteps    | 118400   |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | 0.307    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3699     |
# |    policy_loss        | -1.31    |
# |    std                | 0.806    |
# |    value_loss         | 1.2e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20       |
# |    ep_rew_mean        | 174      |
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 3800     |
# |    time_elapsed       | 375      |
# |    total_timesteps    | 121600   |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | 0.285    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3799     |
# |    policy_loss        | 39.9     |
# |    std                | 0.803    |
# |    value_loss         | 1.81e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.1     |
# |    ep_rew_mean        | 166      |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 3900     |
# |    time_elapsed       | 383      |
# |    total_timesteps    | 124800   |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | 0.431    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3899     |
# |    policy_loss        | 5.84     |
# |    std                | 0.803    |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.4     |
# |    ep_rew_mean        | 178      |
# | time/                 |          |
# |    fps                | 327      |
# |    iterations         | 4000     |
# |    time_elapsed       | 390      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -1.2     |
# |    explained_variance | 0.359    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 3999     |
# |    policy_loss        | 52.3     |
# |    std                | 0.804    |
# |    value_loss         | 3.85e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.9     |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 329      |
# |    iterations         | 4100     |
# |    time_elapsed       | 397      |
# |    total_timesteps    | 131200   |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | 0.688    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.136    |
# |    std                | 0.799    |
# |    value_loss         | 411      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.8     |
# |    ep_rew_mean        | 181      |
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 4200     |
# |    time_elapsed       | 405      |
# |    total_timesteps    | 134400   |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | 0.489    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4199     |
# |    policy_loss        | 15.5     |
# |    std                | 0.795    |
# |    value_loss         | 1.48e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21       |
# |    ep_rew_mean        | 183      |
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 4300     |
# |    time_elapsed       | 412      |
# |    total_timesteps    | 137600   |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.536    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4299     |
# |    policy_loss        | 30.3     |
# |    std                | 0.789    |
# |    value_loss         | 1.84e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.8     |
# |    ep_rew_mean        | 172      |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 4400     |
# |    time_elapsed       | 419      |
# |    total_timesteps    | 140800   |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.626    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4399     |
# |    policy_loss        | 8.86     |
# |    std                | 0.785    |
# |    value_loss         | 741      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.6     |
# |    ep_rew_mean        | 189      |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 4500     |
# |    time_elapsed       | 426      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.201    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4499     |
# |    policy_loss        | 33.8     |
# |    std                | 0.774    |
# |    value_loss         | 2.75e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.1     |
# |    ep_rew_mean        | 193      |
# | time/                 |          |
# |    fps                | 338      |
# |    iterations         | 4600     |
# |    time_elapsed       | 434      |
# |    total_timesteps    | 147200   |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.68     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4599     |
# |    policy_loss        | 38.1     |
# |    std                | 0.772    |
# |    value_loss         | 1.37e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.6     |
# |    ep_rew_mean        | 189      |
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 4700     |
# |    time_elapsed       | 441      |
# |    total_timesteps    | 150400   |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 0.418    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4699     |
# |    policy_loss        | 34.3     |
# |    std                | 0.768    |
# |    value_loss         | 2.45e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.7     |
# |    ep_rew_mean        | 190      |
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 4800     |
# |    time_elapsed       | 449      |
# |    total_timesteps    | 153600   |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 0.67     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4799     |
# |    policy_loss        | -6.18    |
# |    std                | 0.768    |
# |    value_loss         | 604      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.2     |
# |    ep_rew_mean        | 185      |
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 4900     |
# |    time_elapsed       | 457      |
# |    total_timesteps    | 156800   |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 0.459    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4899     |
# |    policy_loss        | 25.9     |
# |    std                | 0.762    |
# |    value_loss         | 2.39e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.8     |
# |    ep_rew_mean        | 181      |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 5000     |
# |    time_elapsed       | 464      |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | 0.444    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 4999     |
# |    policy_loss        | 32.6     |
# |    std                | 0.758    |
# |    value_loss         | 2.66e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.3     |
# |    ep_rew_mean        | 195      |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 5100     |
# |    time_elapsed       | 473      |
# |    total_timesteps    | 163200   |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | 0.713    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5099     |
# |    policy_loss        | 27       |
# |    std                | 0.753    |
# |    value_loss         | 1.04e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.9     |
# |    ep_rew_mean        | 201      |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 5200     |
# |    time_elapsed       | 496      |
# |    total_timesteps    | 166400   |
# | train/                |          |
# |    entropy_loss       | -1.13    |
# |    explained_variance | 0.614    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5199     |
# |    policy_loss        | 23.4     |
# |    std                | 0.747    |
# |    value_loss         | 1.29e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.8     |
# |    ep_rew_mean        | 190      |
# | time/                 |          |
# |    fps                | 330      |
# |    iterations         | 5300     |
# |    time_elapsed       | 513      |
# |    total_timesteps    | 169600   |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 0.713    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.505    |
# |    std                | 0.744    |
# |    value_loss         | 541      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.5     |
# |    ep_rew_mean        | 206      |
# | time/                 |          |
# |    fps                | 328      |
# |    iterations         | 5400     |
# |    time_elapsed       | 525      |
# |    total_timesteps    | 172800   |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 0.496    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5399     |
# |    policy_loss        | 25.2     |
# |    std                | 0.744    |
# |    value_loss         | 1.96e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.7     |
# |    ep_rew_mean        | 190      |
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 5500     |
# |    time_elapsed       | 544      |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 0.711    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.0343  |
# |    std                | 0.744    |
# |    value_loss         | 653      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.1     |
# |    ep_rew_mean        | 193      |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 5600     |
# |    time_elapsed       | 557      |
# |    total_timesteps    | 179200   |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 0.778    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5599     |
# |    policy_loss        | 3.98     |
# |    std                | 0.74     |
# |    value_loss         | 600      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23       |
# |    ep_rew_mean        | 201      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 5700     |
# |    time_elapsed       | 573      |
# |    total_timesteps    | 182400   |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | 0.409    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5699     |
# |    policy_loss        | 24.8     |
# |    std                | 0.734    |
# |    value_loss         | 2.66e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.5     |
# |    ep_rew_mean        | 197      |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 5800     |
# |    time_elapsed       | 585      |
# |    total_timesteps    | 185600   |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.607    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5799     |
# |    policy_loss        | 46.2     |
# |    std                | 0.73     |
# |    value_loss         | 3.46e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.8     |
# |    ep_rew_mean        | 191      |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 5900     |
# |    time_elapsed       | 595      |
# |    total_timesteps    | 188800   |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.812    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5899     |
# |    policy_loss        | -13.2    |
# |    std                | 0.728    |
# |    value_loss         | 450      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.7     |
# |    ep_rew_mean        | 208      |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 6000     |
# |    time_elapsed       | 604      |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.605    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5999     |
# |    policy_loss        | 17.2     |
# |    std                | 0.727    |
# |    value_loss         | 1.31e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.2     |
# |    ep_rew_mean        | 194      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 6100     |
# |    time_elapsed       | 613      |
# |    total_timesteps    | 195200   |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.614    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6099     |
# |    policy_loss        | 39       |
# |    std                | 0.721    |
# |    value_loss         | 2.77e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.2     |
# |    ep_rew_mean        | 204      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 6200     |
# |    time_elapsed       | 622      |
# |    total_timesteps    | 198400   |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.779    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6199     |
# |    policy_loss        | 12.7     |
# |    std                | 0.72     |
# |    value_loss         | 524      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.6     |
# |    ep_rew_mean        | 217      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 6300     |
# |    time_elapsed       | 633      |
# |    total_timesteps    | 201600   |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.709    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6299     |
# |    policy_loss        | 23.8     |
# |    std                | 0.712    |
# |    value_loss         | 1.36e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.7     |
# |    ep_rew_mean        | 199      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 6400     |
# |    time_elapsed       | 643      |
# |    total_timesteps    | 204800   |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.748    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6399     |
# |    policy_loss        | 24.1     |
# |    std                | 0.71     |
# |    value_loss         | 1.11e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.8     |
# |    ep_rew_mean        | 190      |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 6500     |
# |    time_elapsed       | 654      |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.57     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6499     |
# |    policy_loss        | 8.68     |
# |    std                | 0.708    |
# |    value_loss         | 1.33e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.3     |
# |    ep_rew_mean        | 223      |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 6600     |
# |    time_elapsed       | 664      |
# |    total_timesteps    | 211200   |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.632    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6599     |
# |    policy_loss        | 4.01     |
# |    std                | 0.701    |
# |    value_loss         | 1.16e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.6     |
# |    ep_rew_mean        | 207      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 6700     |
# |    time_elapsed       | 673      |
# |    total_timesteps    | 214400   |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.489    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6699     |
# |    policy_loss        | 33.1     |
# |    std                | 0.698    |
# |    value_loss         | 3.24e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.9     |
# |    ep_rew_mean        | 228      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 6800     |
# |    time_elapsed       | 683      |
# |    total_timesteps    | 217600   |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.205    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6799     |
# |    policy_loss        | 66.1     |
# |    std                | 0.695    |
# |    value_loss         | 5.1e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.4     |
# |    ep_rew_mean        | 206      |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 6900     |
# |    time_elapsed       | 694      |
# |    total_timesteps    | 220800   |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.73     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6899     |
# |    policy_loss        | 3.49     |
# |    std                | 0.694    |
# |    value_loss         | 973      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.9     |
# |    ep_rew_mean        | 210      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 7000     |
# |    time_elapsed       | 703      |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.767    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6999     |
# |    policy_loss        | 15.7     |
# |    std                | 0.694    |
# |    value_loss         | 794      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.4     |
# |    ep_rew_mean        | 223      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 7100     |
# |    time_elapsed       | 713      |
# |    total_timesteps    | 227200   |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.697    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7099     |
# |    policy_loss        | 33.7     |
# |    std                | 0.694    |
# |    value_loss         | 1.61e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.4     |
# |    ep_rew_mean        | 223      |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 7200     |
# |    time_elapsed       | 722      |
# |    total_timesteps    | 230400   |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.628    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7199     |
# |    policy_loss        | -18.9    |
# |    std                | 0.688    |
# |    value_loss         | 961      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.1     |
# |    ep_rew_mean        | 221      |
# | time/                 |          |
# |    fps                | 319      |
# |    iterations         | 7300     |
# |    time_elapsed       | 731      |
# |    total_timesteps    | 233600   |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.663    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7299     |
# |    policy_loss        | 24.5     |
# |    std                | 0.685    |
# |    value_loss         | 1.59e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.4     |
# |    ep_rew_mean        | 224      |
# | time/                 |          |
# |    fps                | 319      |
# |    iterations         | 7400     |
# |    time_elapsed       | 740      |
# |    total_timesteps    | 236800   |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.585    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7399     |
# |    policy_loss        | 30.1     |
# |    std                | 0.681    |
# |    value_loss         | 2.6e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.5     |
# |    ep_rew_mean        | 215      |
# | time/                 |          |
# |    fps                | 320      |
# |    iterations         | 7500     |
# |    time_elapsed       | 749      |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.592    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7499     |
# |    policy_loss        | -24.5    |
# |    std                | 0.677    |
# |    value_loss         | 1.08e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.9     |
# |    ep_rew_mean        | 229      |
# | time/                 |          |
# |    fps                | 320      |
# |    iterations         | 7600     |
# |    time_elapsed       | 758      |
# |    total_timesteps    | 243200   |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.462    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.226    |
# |    std                | 0.669    |
# |    value_loss         | 1.57e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.1     |
# |    ep_rew_mean        | 231      |
# | time/                 |          |
# |    fps                | 320      |
# |    iterations         | 7700     |
# |    time_elapsed       | 768      |
# |    total_timesteps    | 246400   |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.889    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7699     |
# |    policy_loss        | 7.84     |
# |    std                | 0.665    |
# |    value_loss         | 308      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.6     |
# |    ep_rew_mean        | 235      |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 7800     |
# |    time_elapsed       | 777      |
# |    total_timesteps    | 249600   |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7799     |
# |    policy_loss        | 15.1     |
# |    std                | 0.658    |
# |    value_loss         | 764      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.9     |
# |    ep_rew_mean        | 219      |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 7900     |
# |    time_elapsed       | 786      |
# |    total_timesteps    | 252800   |
# | train/                |          |
# |    entropy_loss       | -0.992   |
# |    explained_variance | 0.485    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7899     |
# |    policy_loss        | 2.93     |
# |    std                | 0.652    |
# |    value_loss         | 1.73e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.7     |
# |    ep_rew_mean        | 236      |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 8000     |
# |    time_elapsed       | 795      |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | -0.985   |
# |    explained_variance | 0.595    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 7999     |
# |    policy_loss        | 1.47     |
# |    std                | 0.648    |
# |    value_loss         | 1.01e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.6     |
# |    ep_rew_mean        | 235      |
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 8100     |
# |    time_elapsed       | 804      |
# |    total_timesteps    | 259200   |
# | train/                |          |
# |    entropy_loss       | -0.976   |
# |    explained_variance | 0.47     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8099     |
# |    policy_loss        | 45.5     |
# |    std                | 0.642    |
# |    value_loss         | 3.55e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.2     |
# |    ep_rew_mean        | 250      |
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 8200     |
# |    time_elapsed       | 814      |
# |    total_timesteps    | 262400   |
# | train/                |          |
# |    entropy_loss       | -0.969   |
# |    explained_variance | 0.675    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8199     |
# |    policy_loss        | 17.3     |
# |    std                | 0.638    |
# |    value_loss         | 1.73e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.4     |
# |    ep_rew_mean        | 251      |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 8300     |
# |    time_elapsed       | 825      |
# |    total_timesteps    | 265600   |
# | train/                |          |
# |    entropy_loss       | -0.961   |
# |    explained_variance | 0.0176   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8299     |
# |    policy_loss        | 64.5     |
# |    std                | 0.632    |
# |    value_loss         | 6.92e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.1     |
# |    ep_rew_mean        | 231      |
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 8400     |
# |    time_elapsed       | 834      |
# |    total_timesteps    | 268800   |
# | train/                |          |
# |    entropy_loss       | -0.959   |
# |    explained_variance | 0.532    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8399     |
# |    policy_loss        | 10.6     |
# |    std                | 0.631    |
# |    value_loss         | 2.16e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.9     |
# |    ep_rew_mean        | 275      |
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 8500     |
# |    time_elapsed       | 842      |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -0.952   |
# |    explained_variance | 0.412    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8499     |
# |    policy_loss        | 25.1     |
# |    std                | 0.627    |
# |    value_loss         | 3.81e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.8     |
# |    ep_rew_mean        | 255      |
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 8600     |
# |    time_elapsed       | 849      |
# |    total_timesteps    | 275200   |
# | train/                |          |
# |    entropy_loss       | -0.947   |
# |    explained_variance | 0.799    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8599     |
# |    policy_loss        | 11.2     |
# |    std                | 0.624    |
# |    value_loss         | 815      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.7     |
# |    ep_rew_mean        | 236      |
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 8700     |
# |    time_elapsed       | 856      |
# |    total_timesteps    | 278400   |
# | train/                |          |
# |    entropy_loss       | -0.941   |
# |    explained_variance | 0.852    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8699     |
# |    policy_loss        | -3.26    |
# |    std                | 0.62     |
# |    value_loss         | 409      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.1     |
# |    ep_rew_mean        | 239      |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 8800     |
# |    time_elapsed       | 864      |
# |    total_timesteps    | 281600   |
# | train/                |          |
# |    entropy_loss       | -0.937   |
# |    explained_variance | 0.818    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8799     |
# |    policy_loss        | 28.8     |
# |    std                | 0.618    |
# |    value_loss         | 2.31e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.6     |
# |    ep_rew_mean        | 244      |
# | time/                 |          |
# |    fps                | 323      |
# |    iterations         | 8900     |
# |    time_elapsed       | 879      |
# |    total_timesteps    | 284800   |
# | train/                |          |
# |    entropy_loss       | -0.938   |
# |    explained_variance | 0.773    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8899     |
# |    policy_loss        | 3.59     |
# |    std                | 0.618    |
# |    value_loss         | 930      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.3     |
# |    ep_rew_mean        | 232      |
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 9000     |
# |    time_elapsed       | 888      |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -0.932   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 8999     |
# |    policy_loss        | 12.6     |
# |    std                | 0.615    |
# |    value_loss         | 678      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.8     |
# |    ep_rew_mean        | 264      |
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 9100     |
# |    time_elapsed       | 896      |
# |    total_timesteps    | 291200   |
# | train/                |          |
# |    entropy_loss       | -0.928   |
# |    explained_variance | 0.67     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 9099     |
# |    policy_loss        | -3.81    |
# |    std                | 0.612    |
# |    value_loss         | 1.5e+03  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.9     |
# |    ep_rew_mean        | 247      |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 9200     |
# |    time_elapsed       | 905      |
# |    total_timesteps    | 294400   |
# | train/                |          |
# |    entropy_loss       | -0.923   |
# |    explained_variance | 0.757    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 9199     |
# |    policy_loss        | 29       |
# |    std                | 0.609    |
# |    value_loss         | 2.04e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.5     |
# |    ep_rew_mean        | 253      |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 9300     |
# |    time_elapsed       | 913      |
# |    total_timesteps    | 297600   |
# | train/                |          |
# |    entropy_loss       | -0.914   |
# |    explained_variance | 0.852    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 9299     |
# |    policy_loss        | 16.7     |
# |    std                | 0.604    |
# |    value_loss         | 889      |
# ------------------------------------
# Training complete. Model saved. Training took 919.47 seconds.

# %%
trainer.plot_rewards()
model = A2C.load("a2c_idp_model")
trainer.generate_video(model, video_filename='a2c_idp_video.mp4')
# Out:
# Total reward: 1216.2046189229984
#         <video width=600 controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# # SAC
#
# El algoritmo Soft Actor-Critic (SAC) es un método de aprendizaje por refuerzo que intenta solucionar problemas de otros algoritmos como la complejidad de muestreo, malas propiedades de convergencia, y el requerimiento de un ajuste fino de hiperparámetros. Adicionalmente, SAC es un algoritmo que no busca únicamente maximizar la recompensa, sino que también busca maximizar la entropía. Para comprender mejor este algoritmo, primero se explicará este concepto de entropía y el concepto detrás de <i>Soft Policy Iteration</i>.
#
# Como se mencionó anteriormente, SAC sigue el principio de máxima entropía, lo cual quiere decir que no solo se busca maximizar la recompensa, sino también la entropía de la política. Esto se expresa en la Ecuación (4). En este escenario, $R(S_t,A_t)$, $\mathcal{H}(\pi(\cdot|S_t))$ es la entropía de la política y $\alpha$ es un coeficiente (llamado temperatura) que controla cuánto se valora la entropía (exploración) frente a la recompensa. La entropía en aprendizaje por refuerzo dimensiona cuán impredecible o aleatoria es una política, y una política estocástica con alta entropía explora más. Aumentar la entropía incrementa la exploración, mientras que disminuir la entropía favorece la explotación. La ventaja de esta metodología es que el agente puede alcanzar un comportamiento más robusto que no se estanque en soluciones subóptimas. El proceso de <i>Soft Policy Iteration</i> se refiere al proceso de actualizar la política que regulariza la entropía y también premia la exploración de acciones.
#
# $ J(\pi) = \sum_{t=0}^{\infty} \mathbb{E}_{(s_t, a_t) \sim \rho_\pi} \left[ r(s_t, a_t) + \alpha \mathcal{H}(\pi(\cdot | s_t)) \right] $ &emsp;&emsp;&emsp;$(4)$
#
# En la implementación, SAC generalmente utiliza una política Gaussiana para el actor, y para el crítico utiliza Doble Q-Learning, lo cual implica dos redes neuronales adicionales, lo cual puede ser más costoso computacionalmente, pero da mejores resultados al mitigar los sesgos de maximización. SAC se caracteriza por ser un algoritmo <i>off-policy</i> robusto, y es el estado del arte en muchos problemas de robótica, superando en muchos escenarios a otros algoritmos como Proximal Policy Optimization (PPO) y Deep Deterministic Policy Gradient (DDPG).

# %% [markdown]
# ## Ejercicio Práctico 5
#
# Realice el entrenamiento de un modelo SAC para el ambiente de Inverted Pendulum (tenga en cuenta que SAC corre mejor en CPU)

# %%
# Ejercicio practico 5: SAC en InvertedPendulum
# SAC es off-policy con replay buffer; con redes pequenas conviene CPU.
def create_model(env):
    return SAC(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        buffer_size=100_000,
        learning_starts=1_000,
        batch_size=256,
        tau=0.005,
        gamma=0.99,
        train_freq=1,
        gradient_steps=1,
        verbose=1,
        device="cpu",
    )

trainer = IPTrainer(model_fn=create_model, total_timesteps=20_000)
trainer.train(save_path="sac_ip_model")
# Out:
# Using cpu device
# GPU available? True
# Using device: NVIDIA GeForce RTX 4060 Laptop GPU
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | 4.75     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1832     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 23       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 4        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1722     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 40       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.75     |
# |    ep_rew_mean     | 3.75     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 1600     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 57       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.88     |
# |    ep_rew_mean     | 3.88     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 1697     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 78       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.05     |
# |    ep_rew_mean     | 4.05     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 1727     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 101      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.04     |
# |    ep_rew_mean     | 4.04     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 1745     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 121      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.11     |
# |    ep_rew_mean     | 4.11     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 1803     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 143      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.56     |
# |    ep_rew_mean     | 4.56     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 1853     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 178      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.67     |
# |    ep_rew_mean     | 4.67     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 1879     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 204      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.72     |
# |    ep_rew_mean     | 4.72     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 1856     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 229      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.59     |
# |    ep_rew_mean     | 4.59     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 1841     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 246      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.83     |
# |    ep_rew_mean     | 4.83     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 1863     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 280      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 5        |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 1878     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 312      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.02     |
# |    ep_rew_mean     | 5.02     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 1871     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 337      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.92     |
# |    ep_rew_mean     | 4.92     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 1886     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 355      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.03     |
# |    ep_rew_mean     | 5.03     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 1881     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 386      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 5        |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 1889     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 408      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.89     |
# |    ep_rew_mean     | 4.89     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 1880     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 424      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.83     |
# |    ep_rew_mean     | 4.83     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 1894     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 443      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | 4.75     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 1899     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 460      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 4.73     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 1920     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 481      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.69     |
# |    ep_rew_mean     | 4.69     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 1883     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 501      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.78     |
# |    ep_rew_mean     | 4.78     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 1901     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 532      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.74     |
# |    ep_rew_mean     | 4.74     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1885     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 551      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.74     |
# |    ep_rew_mean     | 4.74     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1883     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 574      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.76     |
# |    ep_rew_mean     | 4.76     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 1887     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 599      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | 4.75     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 1872     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 615      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.94     |
# |    ep_rew_mean     | 4.94     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 1878     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 651      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 5        |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 1888     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 678      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.93     |
# |    ep_rew_mean     | 4.93     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 1876     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 694      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 5.12     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 1887     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 733      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.17     |
# |    ep_rew_mean     | 5.17     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 1896     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 760      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.31     |
# |    ep_rew_mean     | 5.31     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 1937     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 809      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.34     |
# |    ep_rew_mean     | 5.34     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 1948     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 838      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.35     |
# |    ep_rew_mean     | 5.35     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 1952     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 864      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.46     |
# |    ep_rew_mean     | 5.46     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 1960     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 892      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.46     |
# |    ep_rew_mean     | 5.46     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 1962     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 926      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 5.38     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 1978     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 950      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.37     |
# |    ep_rew_mean     | 5.37     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 1994     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 974      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 5.38     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 1982     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 993      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 5.3      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 1352     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1016     |
# | train/             |          |
# |    actor_loss      | -1.59    |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.996    |
# |    ent_coef_loss   | -0.00704 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 5.32     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 913      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1040     |
# | train/             |          |
# |    actor_loss      | -1.91    |
# |    critic_loss     | 0.643    |
# |    ent_coef        | 0.989    |
# |    ent_coef_loss   | -0.0189  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.49     |
# |    ep_rew_mean     | 5.49     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 645      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1073     |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 0.368    |
# |    ent_coef        | 0.979    |
# |    ent_coef_loss   | -0.0357  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.48     |
# |    ep_rew_mean     | 5.48     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 558      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1091     |
# | train/             |          |
# |    actor_loss      | -2.46    |
# |    critic_loss     | 0.348    |
# |    ent_coef        | 0.974    |
# |    ent_coef_loss   | -0.045   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.59     |
# |    ep_rew_mean     | 5.59     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 468      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1119     |
# | train/             |          |
# |    actor_loss      | -2.51    |
# |    critic_loss     | 0.352    |
# |    ent_coef        | 0.966    |
# |    ent_coef_loss   | -0.0594  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.66     |
# |    ep_rew_mean     | 5.66     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 403      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1147     |
# | train/             |          |
# |    actor_loss      | -2.54    |
# |    critic_loss     | 0.433    |
# |    ent_coef        | 0.957    |
# |    ent_coef_loss   | -0.0736  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 146      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.75     |
# |    ep_rew_mean     | 5.75     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 355      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1176     |
# | train/             |          |
# |    actor_loss      | -2.64    |
# |    critic_loss     | 0.399    |
# |    ent_coef        | 0.949    |
# |    ent_coef_loss   | -0.0874  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 175      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.67     |
# |    ep_rew_mean     | 5.67     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 325      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1199     |
# | train/             |          |
# |    actor_loss      | -2.7     |
# |    critic_loss     | 0.5      |
# |    ent_coef        | 0.943    |
# |    ent_coef_loss   | -0.0982  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 198      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.72     |
# |    ep_rew_mean     | 5.72     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 299      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1223     |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.431    |
# |    ent_coef        | 0.936    |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 222      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.84     |
# |    ep_rew_mean     | 5.84     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 271      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1258     |
# | train/             |          |
# |    actor_loss      | -2.92    |
# |    critic_loss     | 0.378    |
# |    ent_coef        | 0.926    |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 257      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.04     |
# |    ep_rew_mean     | 6.04     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 244      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1303     |
# | train/             |          |
# |    actor_loss      | -3.19    |
# |    critic_loss     | 0.409    |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.142   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 302      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.57     |
# |    ep_rew_mean     | 6.57     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 213      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1372     |
# | train/             |          |
# |    actor_loss      | -3.44    |
# |    critic_loss     | 0.444    |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 371      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.99     |
# |    ep_rew_mean     | 6.99     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 189      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1450     |
# | train/             |          |
# |    actor_loss      | -3.79    |
# |    critic_loss     | 0.445    |
# |    ent_coef        | 0.877    |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 449      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.18     |
# |    ep_rew_mean     | 7.18     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 178      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1496     |
# | train/             |          |
# |    actor_loss      | -3.9     |
# |    critic_loss     | 0.443    |
# |    ent_coef        | 0.865    |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 495      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.7      |
# |    ep_rew_mean     | 7.7      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 166      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1564     |
# | train/             |          |
# |    actor_loss      | -4.11    |
# |    critic_loss     | 0.464    |
# |    ent_coef        | 0.849    |
# |    ent_coef_loss   | -0.225   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 563      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.03     |
# |    ep_rew_mean     | 8.03     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 155      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1636     |
# | train/             |          |
# |    actor_loss      | -4.65    |
# |    critic_loss     | 0.65     |
# |    ent_coef        | 0.833    |
# |    ent_coef_loss   | -0.243   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 635      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.7     |
# |    ep_rew_mean     | 9.73     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 134      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1833     |
# | train/             |          |
# |    actor_loss      | -5.66    |
# |    critic_loss     | 0.374    |
# |    ent_coef        | 0.792    |
# |    ent_coef_loss   | -0.284   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 832      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.6     |
# |    ep_rew_mean     | 11.6     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 118      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2073     |
# | train/             |          |
# |    actor_loss      | -6.82    |
# |    critic_loss     | 0.807    |
# |    ent_coef        | 0.746    |
# |    ent_coef_loss   | -0.348   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1072     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.8     |
# |    ep_rew_mean     | 13.8     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 109      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2318     |
# | train/             |          |
# |    actor_loss      | -8.13    |
# |    critic_loss     | 0.561    |
# |    ent_coef        | 0.701    |
# |    ent_coef_loss   | -0.378   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1317     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.9     |
# |    ep_rew_mean     | 16.9     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 100      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2653     |
# | train/             |          |
# |    actor_loss      | -9.68    |
# |    critic_loss     | 0.619    |
# |    ent_coef        | 0.644    |
# |    ent_coef_loss   | -0.441   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1652     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 93       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 3055     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.779    |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | -0.575   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | 23.7     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 89       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 3397     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.827    |
# |    ent_coef        | 0.53     |
# |    ent_coef_loss   | -0.705   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2396     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.6     |
# |    ep_rew_mean     | 27.6     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 85       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 3813     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 1.66     |
# |    ent_coef        | 0.475    |
# |    ent_coef_loss   | -0.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2812     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.8     |
# |    ep_rew_mean     | 31.8     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 82       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 4249     |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.422    |
# |    ent_coef_loss   | -0.811   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3248     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 35       |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 80       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 4594     |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.73     |
# |    ent_coef        | 0.384    |
# |    ent_coef_loss   | -0.955   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3593     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39       |
# |    ep_rew_mean     | 38       |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 79       |
# |    time_elapsed    | 62       |
# |    total_timesteps | 4913     |
# | train/             |          |
# |    actor_loss      | -19.1    |
# |    critic_loss     | 0.838    |
# |    ent_coef        | 0.352    |
# |    ent_coef_loss   | -0.889   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3912     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.9     |
# |    ep_rew_mean     | 40.9     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 77       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 5232     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 1.82     |
# |    ent_coef        | 0.322    |
# |    ent_coef_loss   | -0.851   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4231     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.9     |
# |    ep_rew_mean     | 43.9     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 76       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 5560     |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 0.872    |
# |    ent_coef        | 0.294    |
# |    ent_coef_loss   | -0.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4559     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | 47.2     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 75       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 5913     |
# | train/             |          |
# |    actor_loss      | -21.2    |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.266    |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4912     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.5     |
# |    ep_rew_mean     | 50.5     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 74       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 6267     |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 1.88     |
# |    ent_coef        | 0.241    |
# |    ent_coef_loss   | -0.952   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5266     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.7     |
# |    ep_rew_mean     | 53.7     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 70       |
# |    time_elapsed    | 94       |
# |    total_timesteps | 6616     |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.219    |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5615     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.1     |
# |    ep_rew_mean     | 58.1     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 66       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 7087     |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.191    |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6086     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.5     |
# |    ep_rew_mean     | 62.5     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 65       |
# |    time_elapsed    | 114      |
# |    total_timesteps | 7549     |
# | train/             |          |
# |    actor_loss      | -25.9    |
# |    critic_loss     | 1.43     |
# |    ent_coef        | 0.169    |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6548     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 68       |
# |    ep_rew_mean     | 67       |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 66       |
# |    time_elapsed    | 121      |
# |    total_timesteps | 8025     |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 2.01     |
# |    ent_coef        | 0.148    |
# |    ent_coef_loss   | -1.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7024     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.1     |
# |    ep_rew_mean     | 72.1     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 66       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 8565     |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 3.14     |
# |    ent_coef        | 0.128    |
# |    ent_coef_loss   | -0.73    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7564     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.5     |
# |    ep_rew_mean     | 76.5     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 66       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 9052     |
# | train/             |          |
# |    actor_loss      | -28.6    |
# |    critic_loss     | 0.609    |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8051     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80.9     |
# |    ep_rew_mean     | 79.9     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 67       |
# |    time_elapsed    | 141      |
# |    total_timesteps | 9458     |
# | train/             |          |
# |    actor_loss      | -29.9    |
# |    critic_loss     | 0.922    |
# |    ent_coef        | 0.101    |
# |    ent_coef_loss   | -1.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8457     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.3     |
# |    ep_rew_mean     | 83.3     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 67       |
# |    time_elapsed    | 146      |
# |    total_timesteps | 9883     |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 2.47     |
# |    ent_coef        | 0.0904   |
# |    ent_coef_loss   | -1.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8882     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.3     |
# |    ep_rew_mean     | 87.3     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 67       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 10327    |
# | train/             |          |
# |    actor_loss      | -31.1    |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.0803   |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9326     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93       |
# |    ep_rew_mean     | 92       |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 67       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 10859    |
# | train/             |          |
# |    actor_loss      | -32.6    |
# |    critic_loss     | 0.401    |
# |    ent_coef        | 0.0704   |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9858     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.4     |
# |    ep_rew_mean     | 95.4     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 67       |
# |    time_elapsed    | 166      |
# |    total_timesteps | 11279    |
# | train/             |          |
# |    actor_loss      | -30.7    |
# |    critic_loss     | 0.901    |
# |    ent_coef        | 0.0639   |
# |    ent_coef_loss   | -0.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10278    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.3     |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 67       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 11660    |
# | train/             |          |
# |    actor_loss      | -31.7    |
# |    critic_loss     | 0.429    |
# |    ent_coef        | 0.0586   |
# |    ent_coef_loss   | -0.781   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10659    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 98       |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 66       |
# |    time_elapsed    | 178      |
# |    total_timesteps | 11975    |
# | train/             |          |
# |    actor_loss      | -33.2    |
# |    critic_loss     | 0.873    |
# |    ent_coef        | 0.055    |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10974    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 99.2     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 65       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 12336    |
# | train/             |          |
# |    actor_loss      | -33.8    |
# |    critic_loss     | 4.94     |
# |    ent_coef        | 0.0518   |
# |    ent_coef_loss   | -0.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11335    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 64       |
# |    time_elapsed    | 198      |
# |    total_timesteps | 12752    |
# | train/             |          |
# |    actor_loss      | -33.1    |
# |    critic_loss     | 0.562    |
# |    ent_coef        | 0.0481   |
# |    ent_coef_loss   | 0.0837   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11751    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 99.7     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 63       |
# |    time_elapsed    | 206      |
# |    total_timesteps | 13127    |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.0458   |
# |    ent_coef_loss   | 0.143    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12126    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 62       |
# |    time_elapsed    | 215      |
# |    total_timesteps | 13515    |
# | train/             |          |
# |    actor_loss      | -33.8    |
# |    critic_loss     | 0.628    |
# |    ent_coef        | 0.0446   |
# |    ent_coef_loss   | -0.188   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12514    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 61       |
# |    time_elapsed    | 226      |
# |    total_timesteps | 13963    |
# | train/             |          |
# |    actor_loss      | -36      |
# |    critic_loss     | 0.367    |
# |    ent_coef        | 0.0432   |
# |    ent_coef_loss   | -0.593   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12962    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 60       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 14471    |
# | train/             |          |
# |    actor_loss      | -34.6    |
# |    critic_loss     | 0.938    |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | 0.647    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13470    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 59       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 15100    |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 0.382    |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | 0.293    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 56       |
# |    time_elapsed    | 294      |
# |    total_timesteps | 16638    |
# | train/             |          |
# |    actor_loss      | -39.6    |
# |    critic_loss     | 0.846    |
# |    ent_coef        | 0.0442   |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15637    |
# ---------------------------------
# Training complete. Model saved. Training took 354.48 seconds.

# %%
trainer.plot_rewards()
model = SAC.load("sac_ip_model")
trainer.generate_video(model, video_filename='sac_ip_video.mp4')
# Out:
# Total reward: 1000
#         <video width=600 controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# # Entrenamiento de agentes SAC para Inverted Pendulum

# %% [markdown]
# En la siguiente celda de código se encuentra la clase encargada del entrenamiento de agentes para el ambiente de Inverted Double Pendulum

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# En la siguiente celda se muestra el entrenamiento y los resultados para un agente SAC durante 10000 interacciones con el ambiente

# %%
def create_model(env):
    return SAC(
        "MlpPolicy",
        env,
        verbose=1,
        device="cpu"
    )

trainer = IDPTrainer(model_fn=create_model, total_timesteps=10_000)
trainer.train(save_path="sac_idp_model")
# Out:
# Using cpu device
# GPU available? True
# Using device: NVIDIA GeForce RTX 4060 Laptop GPU
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.75     |
# |    ep_rew_mean     | 51.3     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 775      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 27       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.88     |
# |    ep_rew_mean     | 43.4     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 753      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 47       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.33     |
# |    ep_rew_mean     | 47.6     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 744      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 76       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.06     |
# |    ep_rew_mean     | 45.1     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 725      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | 46.9     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 102      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 125      |
# | train/             |          |
# |    actor_loss      | -3.55    |
# |    critic_loss     | 52.4     |
# |    ent_coef        | 0.993    |
# |    ent_coef_loss   | -0.0117  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.21     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 67       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 149      |
# | train/             |          |
# |    actor_loss      | -6.48    |
# |    critic_loss     | 42.6     |
# |    ent_coef        | 0.986    |
# |    ent_coef_loss   | -0.024   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.5      |
# |    ep_rew_mean     | 49.2     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 52       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 182      |
# | train/             |          |
# |    actor_loss      | -7.41    |
# |    critic_loss     | 32.4     |
# |    ent_coef        | 0.976    |
# |    ent_coef_loss   | -0.0407  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 81       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.22     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 49       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 199      |
# | train/             |          |
# |    actor_loss      | -8.57    |
# |    critic_loss     | 26       |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.0488  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.36     |
# |    ep_rew_mean     | 47.9     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 44       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 229      |
# | train/             |          |
# |    actor_loss      | -9.83    |
# |    critic_loss     | 16.9     |
# |    ent_coef        | 0.963    |
# |    ent_coef_loss   | -0.061   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 128      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.15     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 41       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 246      |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 16.9     |
# |    ent_coef        | 0.958    |
# |    ent_coef_loss   | -0.0681  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 145      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.14     |
# |    ep_rew_mean     | 45.8     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 38       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 270      |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.951    |
# |    ent_coef_loss   | -0.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 169      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 45.5     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 38       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 293      |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.945    |
# |    ent_coef_loss   | -0.0907  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 192      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 45.4     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 38       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 317      |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | -0.101   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 216      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.05     |
# |    ep_rew_mean     | 45       |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 37       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 339      |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.112   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 238      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.15     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 36       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 369      |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 9.89     |
# |    ent_coef        | 0.924    |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.03     |
# |    ep_rew_mean     | 44.8     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 36       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 386      |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.919    |
# |    ent_coef_loss   | -0.128   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 285      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 45.5     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 37       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 415      |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 7.7      |
# |    ent_coef        | 0.912    |
# |    ent_coef_loss   | -0.143   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 314      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.7     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 39       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 441      |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 9.12     |
# |    ent_coef        | 0.905    |
# |    ent_coef_loss   | -0.147   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 340      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.21     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 40       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 472      |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 7.87     |
# |    ent_coef        | 0.897    |
# |    ent_coef_loss   | -0.152   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 371      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.26     |
# |    ep_rew_mean     | 47       |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 41       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 501      |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 5.36     |
# |    ent_coef        | 0.89     |
# |    ent_coef_loss   | -0.166   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 400      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.35     |
# |    ep_rew_mean     | 47.7     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 42       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 533      |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 6.43     |
# |    ent_coef        | 0.883    |
# |    ent_coef_loss   | -0.148   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 432      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.43     |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 43       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 566      |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 7.63     |
# |    ent_coef        | 0.876    |
# |    ent_coef_loss   | -0.165   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 465      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.49     |
# |    ep_rew_mean     | 49       |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 44       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 597      |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 6.44     |
# |    ent_coef        | 0.869    |
# |    ent_coef_loss   | -0.181   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 496      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.56     |
# |    ep_rew_mean     | 49.7     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 45       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 630      |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 5.92     |
# |    ent_coef        | 0.862    |
# |    ent_coef_loss   | -0.178   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 529      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.61     |
# |    ep_rew_mean     | 50.2     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 45       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 661      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 5.15     |
# |    ent_coef        | 0.855    |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 560      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.69     |
# |    ep_rew_mean     | 50.9     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 46       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 696      |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 4.74     |
# |    ent_coef        | 0.848    |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 595      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.89     |
# |    ep_rew_mean     | 52.8     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 47       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 736      |
# | train/             |          |
# |    actor_loss      | -21.4    |
# |    critic_loss     | 6.18     |
# |    ent_coef        | 0.84     |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 635      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.88     |
# |    ep_rew_mean     | 52.7     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 48       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 764      |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 3.88     |
# |    ent_coef        | 0.835    |
# |    ent_coef_loss   | -0.187   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 663      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.09     |
# |    ep_rew_mean     | 54.7     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 48       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 806      |
# | train/             |          |
# |    actor_loss      | -22.2    |
# |    critic_loss     | 4.73     |
# |    ent_coef        | 0.827    |
# |    ent_coef_loss   | -0.199   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 705      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.18     |
# |    ep_rew_mean     | 55.5     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 49       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 843      |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 6.6      |
# |    ent_coef        | 0.821    |
# |    ent_coef_loss   | -0.195   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 742      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.33     |
# |    ep_rew_mean     | 56.9     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 50       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 882      |
# | train/             |          |
# |    actor_loss      | -24.3    |
# |    critic_loss     | 5.72     |
# |    ent_coef        | 0.814    |
# |    ent_coef_loss   | -0.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 781      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.4      |
# |    ep_rew_mean     | 57.6     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 51       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 922      |
# | train/             |          |
# |    actor_loss      | -26.8    |
# |    critic_loss     | 6.31     |
# |    ent_coef        | 0.807    |
# |    ent_coef_loss   | -0.203   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 821      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.64     |
# |    ep_rew_mean     | 59.8     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 51       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 963      |
# | train/             |          |
# |    actor_loss      | -26.1    |
# |    critic_loss     | 4.49     |
# |    ent_coef        | 0.8      |
# |    ent_coef_loss   | -0.209   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 862      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.89     |
# |    ep_rew_mean     | 62.2     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 52       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1018     |
# | train/             |          |
# |    actor_loss      | -28.5    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.791    |
# |    ent_coef_loss   | -0.191   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 917      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.19     |
# |    ep_rew_mean     | 65       |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 53       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1065     |
# | train/             |          |
# |    actor_loss      | -28.4    |
# |    critic_loss     | 9.31     |
# |    ent_coef        | 0.783    |
# |    ent_coef_loss   | -0.189   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 964      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.43     |
# |    ep_rew_mean     | 67.2     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 53       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1113     |
# | train/             |          |
# |    actor_loss      | -31.8    |
# |    critic_loss     | 9.8      |
# |    ent_coef        | 0.775    |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1012     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.69     |
# |    ep_rew_mean     | 69.7     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 54       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1162     |
# | train/             |          |
# |    actor_loss      | -32.8    |
# |    critic_loss     | 4.4      |
# |    ent_coef        | 0.768    |
# |    ent_coef_loss   | -0.213   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1061     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.92     |
# |    ep_rew_mean     | 71.8     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 54       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1209     |
# | train/             |          |
# |    actor_loss      | -32.6    |
# |    critic_loss     | 8.33     |
# |    ent_coef        | 0.761    |
# |    ent_coef_loss   | -0.169   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1108     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.11     |
# |    ep_rew_mean     | 73.6     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 55       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1250     |
# | train/             |          |
# |    actor_loss      | -31.8    |
# |    critic_loss     | 5.67     |
# |    ent_coef        | 0.754    |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1149     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.49     |
# |    ep_rew_mean     | 77.2     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 55       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1318     |
# | train/             |          |
# |    actor_loss      | -32.7    |
# |    critic_loss     | 6.09     |
# |    ent_coef        | 0.745    |
# |    ent_coef_loss   | -0.206   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1217     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.1     |
# |    ep_rew_mean     | 82.6     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 56       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1393     |
# | train/             |          |
# |    actor_loss      | -35.2    |
# |    critic_loss     | 9.75     |
# |    ent_coef        | 0.734    |
# |    ent_coef_loss   | -0.224   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1292     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.4     |
# |    ep_rew_mean     | 85.4     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 56       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1452     |
# | train/             |          |
# |    actor_loss      | -38.1    |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.726    |
# |    ent_coef_loss   | -0.211   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1351     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.9     |
# |    ep_rew_mean     | 90       |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 57       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1527     |
# | train/             |          |
# |    actor_loss      | -39.9    |
# |    critic_loss     | 16.7     |
# |    ent_coef        | 0.717    |
# |    ent_coef_loss   | -0.206   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1426     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.3     |
# |    ep_rew_mean     | 94.2     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 57       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1604     |
# | train/             |          |
# |    actor_loss      | -41.7    |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.708    |
# |    ent_coef_loss   | -0.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1503     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.7     |
# |    ep_rew_mean     | 97.9     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 58       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1672     |
# | train/             |          |
# |    actor_loss      | -44.8    |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.701    |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1571     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.3     |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 58       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 1761     |
# | train/             |          |
# |    actor_loss      | -43.8    |
# |    critic_loss     | 7.94     |
# |    ent_coef        | 0.691    |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1660     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.7     |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 59       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1833     |
# | train/             |          |
# |    actor_loss      | -47.4    |
# |    critic_loss     | 8.32     |
# |    ent_coef        | 0.684    |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1732     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.4     |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 59       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 1933     |
# | train/             |          |
# |    actor_loss      | -51.8    |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.674    |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1832     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.8     |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 60       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2007     |
# | train/             |          |
# |    actor_loss      | -51.8    |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.667    |
# |    ent_coef_loss   | -0.149   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1906     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.5     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 60       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2108     |
# | train/             |          |
# |    actor_loss      | -53.9    |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.658    |
# |    ent_coef_loss   | -0.119   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2007     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.1     |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 60       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 2206     |
# | train/             |          |
# |    actor_loss      | -57.6    |
# |    critic_loss     | 7.21     |
# |    ent_coef        | 0.651    |
# |    ent_coef_loss   | -0.0996  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2105     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.7     |
# |    ep_rew_mean     | 135      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 61       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2309     |
# | train/             |          |
# |    actor_loss      | -61.2    |
# |    critic_loss     | 7.04     |
# |    ent_coef        | 0.643    |
# |    ent_coef_loss   | -0.124   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2208     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.2     |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 61       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2383     |
# | train/             |          |
# |    actor_loss      | -61.3    |
# |    critic_loss     | 7.46     |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -0.0659  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2282     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17       |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 61       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2502     |
# | train/             |          |
# |    actor_loss      | -64.3    |
# |    critic_loss     | 6.93     |
# |    ent_coef        | 0.63     |
# |    ent_coef_loss   | -0.0656  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2401     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.7     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 62       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2610     |
# | train/             |          |
# |    actor_loss      | -71.4    |
# |    critic_loss     | 8.04     |
# |    ent_coef        | 0.624    |
# |    ent_coef_loss   | -0.0972  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2509     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.4     |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 62       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2717     |
# | train/             |          |
# |    actor_loss      | -66.7    |
# |    critic_loss     | 6.78     |
# |    ent_coef        | 0.619    |
# |    ent_coef_loss   | -0.0479  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2616     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.3     |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 62       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 2854     |
# | train/             |          |
# |    actor_loss      | -73.7    |
# |    critic_loss     | 6.69     |
# |    ent_coef        | 0.615    |
# |    ent_coef_loss   | -0.0403  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2753     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 63       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 2998     |
# | train/             |          |
# |    actor_loss      | -72.3    |
# |    critic_loss     | 7.03     |
# |    ent_coef        | 0.612    |
# |    ent_coef_loss   | -0.0128  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2897     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 63       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 3124     |
# | train/             |          |
# |    actor_loss      | -74.4    |
# |    critic_loss     | 8.04     |
# |    ent_coef        | 0.612    |
# |    ent_coef_loss   | -0.0467  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3023     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 63       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3250     |
# | train/             |          |
# |    actor_loss      | -80.7    |
# |    critic_loss     | 7.97     |
# |    ent_coef        | 0.613    |
# |    ent_coef_loss   | -0.0208  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3149     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 63       |
# |    time_elapsed    | 53       |
# |    total_timesteps | 3397     |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 8.31     |
# |    ent_coef        | 0.615    |
# |    ent_coef_loss   | -0.0501  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3296     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | 217      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 64       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 3608     |
# | train/             |          |
# |    actor_loss      | -86.8    |
# |    critic_loss     | 8.31     |
# |    ent_coef        | 0.621    |
# |    ent_coef_loss   | 0.0912   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3507     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.4     |
# |    ep_rew_mean     | 226      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 64       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 3749     |
# | train/             |          |
# |    actor_loss      | -94.5    |
# |    critic_loss     | 13.4     |
# |    ent_coef        | 0.626    |
# |    ent_coef_loss   | 0.0565   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3648     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | 243      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 64       |
# |    time_elapsed    | 61       |
# |    total_timesteps | 3978     |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 7.61     |
# |    ent_coef        | 0.636    |
# |    ent_coef_loss   | 0.0949   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3877     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.2     |
# |    ep_rew_mean     | 252      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 65       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 4138     |
# | train/             |          |
# |    actor_loss      | -99      |
# |    critic_loss     | 8.31     |
# |    ent_coef        | 0.643    |
# |    ent_coef_loss   | -0.041   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4037     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.2     |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 65       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 4415     |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.656    |
# |    ent_coef_loss   | 0.00412  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4314     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.4     |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 65       |
# |    time_elapsed    | 70       |
# |    total_timesteps | 4597     |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.665    |
# |    ent_coef_loss   | -0.0287  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4496     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.3     |
# |    ep_rew_mean     | 299      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 65       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 4854     |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 6.19     |
# |    ent_coef        | 0.673    |
# |    ent_coef_loss   | 0.0029   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4753     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | 313      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 66       |
# |    time_elapsed    | 76       |
# |    total_timesteps | 5082     |
# | train/             |          |
# |    actor_loss      | -122     |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.68     |
# |    ent_coef_loss   | 0.00878  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4981     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 324      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 66       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 5269     |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 8.42     |
# |    ent_coef        | 0.685    |
# |    ent_coef_loss   | 0.0679   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5168     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.7     |
# |    ep_rew_mean     | 332      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 66       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 5434     |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.687    |
# |    ent_coef_loss   | 0.00594  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5333     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.7     |
# |    ep_rew_mean     | 340      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 66       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 5601     |
# | train/             |          |
# |    actor_loss      | -137     |
# |    critic_loss     | 11.8     |
# |    ent_coef        | 0.689    |
# |    ent_coef_loss   | -0.0196  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5500     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.7     |
# |    ep_rew_mean     | 350      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 66       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 5802     |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 7.78     |
# |    ent_coef        | 0.689    |
# |    ent_coef_loss   | -0.00785 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5701     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.6     |
# |    ep_rew_mean     | 358      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 66       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 5965     |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.69     |
# |    ent_coef_loss   | 0.0436   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5864     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.9     |
# |    ep_rew_mean     | 361      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 67       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 6098     |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.692    |
# |    ent_coef_loss   | 0.0232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5997     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.5     |
# |    ep_rew_mean     | 367      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 67       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 6255     |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.695    |
# |    ent_coef_loss   | -0.0134  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6154     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | 382      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 67       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 6527     |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 8.29     |
# |    ent_coef        | 0.708    |
# |    ent_coef_loss   | -0.0293  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6426     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45       |
# |    ep_rew_mean     | 409      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 67       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 6885     |
# | train/             |          |
# |    actor_loss      | -152     |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.73     |
# |    ent_coef_loss   | -0.018   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6784     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | 437      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 67       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 7303     |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 8.09     |
# |    ent_coef        | 0.768    |
# |    ent_coef_loss   | -0.0196  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7202     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 455      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 67       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 7599     |
# | train/             |          |
# |    actor_loss      | -169     |
# |    critic_loss     | 7.87     |
# |    ent_coef        | 0.8      |
# |    ent_coef_loss   | 0.0459   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7498     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.7     |
# |    ep_rew_mean     | 481      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 67       |
# |    time_elapsed    | 117      |
# |    total_timesteps | 7984     |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 10       |
# |    ent_coef        | 0.847    |
# |    ent_coef_loss   | -0.00435 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7883     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.6     |
# |    ep_rew_mean     | 518      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 67       |
# |    time_elapsed    | 125      |
# |    total_timesteps | 8517     |
# | train/             |          |
# |    actor_loss      | -178     |
# |    critic_loss     | 7.8      |
# |    ent_coef        | 0.901    |
# |    ent_coef_loss   | 0.00841  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8416     |
# ---------------------------------
# Training complete. Model saved. Training took 146.32 seconds.

# %%
trainer.plot_rewards()
model = SAC.load("sac_idp_model")
trainer.generate_video(model,video_filename='sac_idp_video.mp4')
# Out:
# Total reward: 4732.598969895387
#         <video width=600 controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# ## Ejecicio Práctico 6
#
# Reduzca la tasa de aprendizaje y aumente el n_steps para obtener un aprendizaje más estable para el modelo SAC

# %%
# Ejercicio practico 6: SAC en InvertedDoublePendulum con hiperparametros ajustados
# - learning_rate reducido (3e-4 -> 1e-4) para mayor estabilidad
# - SAC no expone n_steps como A2C; aumentamos gradient_steps y train_freq,
#   que controlan cuantos pasos de optimizacion se hacen por interaccion.
def create_model(env):
    return SAC(
        "MlpPolicy",
        env,
        learning_rate=1e-4,
        buffer_size=200_000,
        learning_starts=2_000,
        batch_size=256,
        tau=0.005,
        gamma=0.99,
        train_freq=4,
        gradient_steps=4,
        verbose=1,
        device="cpu",
    )

trainer = IDPTrainer(model_fn=create_model, total_timesteps=30_000)
trainer.train(save_path="sac_idp_model1")
# Out:
# Using cpu device
# GPU available? True
# Using device: NVIDIA GeForce RTX 4060 Laptop GPU
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.5      |
# |    ep_rew_mean     | 58.7     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1049     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 30       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 48.2     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1243     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 51       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | 47       |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 1286     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 75       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.88     |
# |    ep_rew_mean     | 43.4     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 1335     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 94       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 44.6     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 1265     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 120      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.92     |
# |    ep_rew_mean     | 43.8     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 1227     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 142      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.43     |
# |    ep_rew_mean     | 48.6     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 1233     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 180      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.34     |
# |    ep_rew_mean     | 47.8     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 1193     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 203      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.53     |
# |    ep_rew_mean     | 49.5     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 1199     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 235      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.62     |
# |    ep_rew_mean     | 50.4     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 1202     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 265      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.66     |
# |    ep_rew_mean     | 50.7     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 1210     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 293      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.71     |
# |    ep_rew_mean     | 51.2     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 1190     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 322      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.63     |
# |    ep_rew_mean     | 50.5     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 1156     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 345      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.77     |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 1140     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 379      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.8      |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 1134     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 408      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.77     |
# |    ep_rew_mean     | 51.6     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 1121     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 433      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.75     |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 1130     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 459      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.75     |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 1118     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 486      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.75     |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 1131     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 513      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.81     |
# |    ep_rew_mean     | 52.1     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 1142     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 545      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.73     |
# |    ep_rew_mean     | 51.3     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 1150     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 565      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.77     |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 1148     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 596      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.79     |
# |    ep_rew_mean     | 51.9     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 1142     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 625      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.82     |
# |    ep_rew_mean     | 52.2     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1139     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 655      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.78     |
# |    ep_rew_mean     | 51.8     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 1138     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 678      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.75     |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 1146     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 705      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.79     |
# |    ep_rew_mean     | 51.9     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 1137     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 730      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.81     |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 1129     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 756      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.91     |
# |    ep_rew_mean     | 53       |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 1137     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 785      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.9      |
# |    ep_rew_mean     | 52.9     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 1137     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 810      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.92     |
# |    ep_rew_mean     | 53.1     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 1154     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 834      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.78     |
# |    ep_rew_mean     | 51.7     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 1148     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 858      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.79     |
# |    ep_rew_mean     | 51.8     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 1146     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 882      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.7      |
# |    ep_rew_mean     | 51       |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 1142     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 905      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.66     |
# |    ep_rew_mean     | 50.6     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 1129     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 931      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.61     |
# |    ep_rew_mean     | 50.2     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 1125     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 954      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.58     |
# |    ep_rew_mean     | 49.9     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 1130     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 980      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.58     |
# |    ep_rew_mean     | 49.9     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 1137     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1003     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.51     |
# |    ep_rew_mean     | 49.2     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 1134     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1030     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.47     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 1134     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1055     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.45     |
# |    ep_rew_mean     | 48.7     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 1137     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1078     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.44     |
# |    ep_rew_mean     | 48.6     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 1137     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1103     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.4      |
# |    ep_rew_mean     | 48.2     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 1136     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1126     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.48     |
# |    ep_rew_mean     | 49       |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 1133     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1161     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.36     |
# |    ep_rew_mean     | 47.9     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 1126     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1181     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.45     |
# |    ep_rew_mean     | 48.7     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 1122     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1210     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.41     |
# |    ep_rew_mean     | 48.3     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 1121     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1237     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.37     |
# |    ep_rew_mean     | 48       |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 1099     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1262     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.33     |
# |    ep_rew_mean     | 47.6     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 1093     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.31     |
# |    ep_rew_mean     | 47.4     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 1083     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1309     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.29     |
# |    ep_rew_mean     | 47.2     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 1077     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1334     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.36     |
# |    ep_rew_mean     | 47.9     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 1082     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1366     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 1082     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1388     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.31     |
# |    ep_rew_mean     | 47.4     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 1096     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1416     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 1092     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1442     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 47.3     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 1095     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1464     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.27     |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 1093     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1485     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.28     |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 1081     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1510     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 47.3     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 1082     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1535     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 47.3     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 1077     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1561     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 47.3     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 1071     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1584     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 47.4     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 1085     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1610     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 1079     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1635     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 47.6     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 1078     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1662     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.37     |
# |    ep_rew_mean     | 48       |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 1085     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1692     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.42     |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 1079     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1720     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.46     |
# |    ep_rew_mean     | 48.8     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 1073     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1749     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.48     |
# |    ep_rew_mean     | 49       |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 1075     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1774     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.37     |
# |    ep_rew_mean     | 48       |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 1075     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1798     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.4      |
# |    ep_rew_mean     | 48.3     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 1070     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1821     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.44     |
# |    ep_rew_mean     | 48.7     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 1076     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1854     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.4      |
# |    ep_rew_mean     | 48.3     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 1073     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1877     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.4      |
# |    ep_rew_mean     | 48.3     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 1070     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1902     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 1067     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1926     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.42     |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 1069     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1951     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.39     |
# |    ep_rew_mean     | 48.2     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 1068     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1973     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.34     |
# |    ep_rew_mean     | 47.7     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 1068     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.35     |
# |    ep_rew_mean     | 47.8     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 784      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2023     |
# | train/             |          |
# |    actor_loss      | -1.22    |
# |    critic_loss     | 71.5     |
# |    ent_coef        | 0.998    |
# |    ent_coef_loss   | -0.00292 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 47.3     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 641      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2046     |
# | train/             |          |
# |    actor_loss      | -2.32    |
# |    critic_loss     | 59.4     |
# |    ent_coef        | 0.996    |
# |    ent_coef_loss   | -0.00701 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 44       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.3      |
# |    ep_rew_mean     | 47.3     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 548      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2072     |
# | train/             |          |
# |    actor_loss      | -3.57    |
# |    critic_loss     | 53.2     |
# |    ent_coef        | 0.993    |
# |    ent_coef_loss   | -0.0111  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 68       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 446      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2102     |
# | train/             |          |
# |    actor_loss      | -5.24    |
# |    critic_loss     | 47.4     |
# |    ent_coef        | 0.99     |
# |    ent_coef_loss   | -0.0165  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 100      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.43     |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 369      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2128     |
# | train/             |          |
# |    actor_loss      | -6.33    |
# |    critic_loss     | 46.5     |
# |    ent_coef        | 0.988    |
# |    ent_coef_loss   | -0.0205  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 124      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.47     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 315      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2157     |
# | train/             |          |
# |    actor_loss      | -7.12    |
# |    critic_loss     | 44.6     |
# |    ent_coef        | 0.985    |
# |    ent_coef_loss   | -0.026   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 156      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.47     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 284      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2182     |
# | train/             |          |
# |    actor_loss      | -7.65    |
# |    critic_loss     | 46.9     |
# |    ent_coef        | 0.982    |
# |    ent_coef_loss   | -0.03    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 180      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.53     |
# |    ep_rew_mean     | 49.5     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 241      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2214     |
# | train/             |          |
# |    actor_loss      | -8.32    |
# |    critic_loss     | 45.4     |
# |    ent_coef        | 0.979    |
# |    ent_coef_loss   | -0.0352  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 212      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.56     |
# |    ep_rew_mean     | 49.7     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 224      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2240     |
# | train/             |          |
# |    actor_loss      | -9.01    |
# |    critic_loss     | 43       |
# |    ent_coef        | 0.977    |
# |    ent_coef_loss   | -0.0392  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 236      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.53     |
# |    ep_rew_mean     | 49.4     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 217      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2263     |
# | train/             |          |
# |    actor_loss      | -9.74    |
# |    critic_loss     | 40.3     |
# |    ent_coef        | 0.974    |
# |    ent_coef_loss   | -0.0435  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 260      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.56     |
# |    ep_rew_mean     | 49.7     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 212      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2291     |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 38.7     |
# |    ent_coef        | 0.972    |
# |    ent_coef_loss   | -0.0479  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 288      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.55     |
# |    ep_rew_mean     | 49.6     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 207      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2317     |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 35.1     |
# |    ent_coef        | 0.969    |
# |    ent_coef_loss   | -0.0519  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 316      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.53     |
# |    ep_rew_mean     | 49.5     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 202      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2345     |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 34.9     |
# |    ent_coef        | 0.966    |
# |    ent_coef_loss   | -0.0568  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 344      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.47     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 199      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2367     |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 31.2     |
# |    ent_coef        | 0.964    |
# |    ent_coef_loss   | -0.0595  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 364      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.37     |
# |    ep_rew_mean     | 48       |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 197      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2386     |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 31.3     |
# |    ent_coef        | 0.963    |
# |    ent_coef_loss   | -0.0629  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 384      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.31     |
# |    ep_rew_mean     | 47.4     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 194      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2405     |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 29.1     |
# |    ent_coef        | 0.961    |
# |    ent_coef_loss   | -0.0666  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 404      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.27     |
# |    ep_rew_mean     | 47       |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 191      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2425     |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 28.3     |
# |    ent_coef        | 0.959    |
# |    ent_coef_loss   | -0.0692  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 424      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.22     |
# |    ep_rew_mean     | 46.6     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 189      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2443     |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 27       |
# |    ent_coef        | 0.957    |
# |    ent_coef_loss   | -0.072   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 440      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 186      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2466     |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 24       |
# |    ent_coef        | 0.955    |
# |    ent_coef_loss   | -0.0751  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 464      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 183      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2489     |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 26.1     |
# |    ent_coef        | 0.953    |
# |    ent_coef_loss   | -0.0805  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 488      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.11     |
# |    ep_rew_mean     | 45.5     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 180      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2513     |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 23.9     |
# |    ent_coef        | 0.95     |
# |    ent_coef_loss   | -0.0843  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 512      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.15     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 177      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2541     |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.948    |
# |    ent_coef_loss   | -0.0884  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 540      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 45.4     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 175      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2561     |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.946    |
# |    ent_coef_loss   | -0.0927  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 560      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.07     |
# |    ep_rew_mean     | 45.2     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 174      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2580     |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 22.1     |
# |    ent_coef        | 0.944    |
# |    ent_coef_loss   | -0.0955  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 576      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.07     |
# |    ep_rew_mean     | 45.2     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 171      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2607     |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 20.3     |
# |    ent_coef        | 0.942    |
# |    ent_coef_loss   | -0.0984  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 604      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 169      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2635     |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 20.4     |
# |    ent_coef        | 0.939    |
# |    ent_coef_loss   | -0.1     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 632      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.14     |
# |    ep_rew_mean     | 45.8     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 167      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2660     |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 0.937    |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 656      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.16     |
# |    ep_rew_mean     | 46       |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 165      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2688     |
# | train/             |          |
# |    actor_loss      | -19.9    |
# |    critic_loss     | 17.5     |
# |    ent_coef        | 0.934    |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 684      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 162      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2714     |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.101   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 712      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.16     |
# |    ep_rew_mean     | 46       |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 160      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2744     |
# | train/             |          |
# |    actor_loss      | -21.1    |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.93     |
# |    ent_coef_loss   | -0.0995  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 740      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.16     |
# |    ep_rew_mean     | 46       |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 158      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2773     |
# | train/             |          |
# |    actor_loss      | -21.7    |
# |    critic_loss     | 17.6     |
# |    ent_coef        | 0.927    |
# |    ent_coef_loss   | -0.0993  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 772      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.27     |
# |    ep_rew_mean     | 47       |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 156      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 2809     |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.925    |
# |    ent_coef_loss   | -0.0925  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 808      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.28     |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 154      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 2842     |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.922    |
# |    ent_coef_loss   | -0.0892  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 840      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.34     |
# |    ep_rew_mean     | 47.7     |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 151      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 2874     |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.92     |
# |    ent_coef_loss   | -0.0807  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 872      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.46     |
# |    ep_rew_mean     | 48.8     |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 149      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2909     |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.918    |
# |    ent_coef_loss   | -0.0783  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 908      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.62     |
# |    ep_rew_mean     | 50.3     |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 147      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2953     |
# | train/             |          |
# |    actor_loss      | -25.7    |
# |    critic_loss     | 17.6     |
# |    ent_coef        | 0.916    |
# |    ent_coef_loss   | -0.0765  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 952      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.75     |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 145      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2992     |
# | train/             |          |
# |    actor_loss      | -26.6    |
# |    critic_loss     | 15.5     |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.0723  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 988      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.8      |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 143      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 3025     |
# | train/             |          |
# ...
# |    total_timesteps | 15271    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 50.1     |
# |    ent_coef        | 1.16     |
# |    ent_coef_loss   | -3.1e-05 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13268    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.8     |
# |    ep_rew_mean     | 341      |
# | time/              |          |
# |    episodes        | 944      |
# |    fps             | 78       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 15502    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 49.3     |
# |    ent_coef        | 1.17     |
# |    ent_coef_loss   | 0.00502  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13500    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.2     |
# |    ep_rew_mean     | 345      |
# | time/              |          |
# |    episodes        | 948      |
# |    fps             | 78       |
# |    time_elapsed    | 199      |
# |    total_timesteps | 15728    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 43.7     |
# |    ent_coef        | 1.17     |
# |    ent_coef_loss   | 0.0158   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13724    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39       |
# |    ep_rew_mean     | 352      |
# | time/              |          |
# |    episodes        | 952      |
# |    fps             | 78       |
# |    time_elapsed    | 202      |
# |    total_timesteps | 15949    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 1.17     |
# |    ent_coef_loss   | 0.00019  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13948    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.2     |
# |    ep_rew_mean     | 354      |
# | time/              |          |
# |    episodes        | 956      |
# |    fps             | 78       |
# |    time_elapsed    | 204      |
# |    total_timesteps | 16098    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 38.9     |
# |    ent_coef        | 1.18     |
# |    ent_coef_loss   | -0.00466 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14096    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.6     |
# |    ep_rew_mean     | 367      |
# | time/              |          |
# |    episodes        | 960      |
# |    fps             | 78       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 16348    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 45.1     |
# |    ent_coef        | 1.18     |
# |    ent_coef_loss   | 0.00549  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14344    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.4     |
# |    ep_rew_mean     | 375      |
# | time/              |          |
# |    episodes        | 964      |
# |    fps             | 78       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 16585    |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 54.8     |
# |    ent_coef        | 1.19     |
# |    ent_coef_loss   | -0.00265 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14584    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.6     |
# |    ep_rew_mean     | 377      |
# | time/              |          |
# |    episodes        | 968      |
# |    fps             | 78       |
# |    time_elapsed    | 213      |
# |    total_timesteps | 16740    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 45.4     |
# |    ent_coef        | 1.19     |
# |    ent_coef_loss   | 0.00391  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14736    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | 383      |
# | time/              |          |
# |    episodes        | 972      |
# |    fps             | 78       |
# |    time_elapsed    | 217      |
# |    total_timesteps | 16960    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 51.6     |
# |    ent_coef        | 1.2      |
# |    ent_coef_loss   | -0.00343 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14956    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.5     |
# |    ep_rew_mean     | 395      |
# | time/              |          |
# |    episodes        | 976      |
# |    fps             | 78       |
# |    time_elapsed    | 220      |
# |    total_timesteps | 17198    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 48.1     |
# |    ent_coef        | 1.2      |
# |    ent_coef_loss   | -0.00312 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15196    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.1     |
# |    ep_rew_mean     | 401      |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 77       |
# |    time_elapsed    | 223      |
# |    total_timesteps | 17404    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 52.8     |
# |    ent_coef        | 1.21     |
# |    ent_coef_loss   | 0.00715  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.8     |
# |    ep_rew_mean     | 407      |
# | time/              |          |
# |    episodes        | 984      |
# |    fps             | 77       |
# |    time_elapsed    | 225      |
# |    total_timesteps | 17595    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 42       |
# |    ent_coef        | 1.22     |
# |    ent_coef_loss   | 0.0174   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15592    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.8     |
# |    ep_rew_mean     | 407      |
# | time/              |          |
# |    episodes        | 988      |
# |    fps             | 77       |
# |    time_elapsed    | 227      |
# |    total_timesteps | 17722    |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 45.6     |
# |    ent_coef        | 1.22     |
# |    ent_coef_loss   | -0.00994 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15720    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.6     |
# |    ep_rew_mean     | 424      |
# | time/              |          |
# |    episodes        | 992      |
# |    fps             | 77       |
# |    time_elapsed    | 232      |
# |    total_timesteps | 18105    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 48.8     |
# |    ent_coef        | 1.23     |
# |    ent_coef_loss   | -0.0154  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16104    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47       |
# |    ep_rew_mean     | 428      |
# | time/              |          |
# |    episodes        | 996      |
# |    fps             | 77       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 18287    |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 52.1     |
# |    ent_coef        | 1.24     |
# |    ent_coef_loss   | -0.00319 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16284    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.8     |
# |    ep_rew_mean     | 435      |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 77       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 18539    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 49.2     |
# |    ent_coef        | 1.24     |
# |    ent_coef_loss   | 0.00546  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16536    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | 438      |
# | time/              |          |
# |    episodes        | 1004     |
# |    fps             | 77       |
# |    time_elapsed    | 241      |
# |    total_timesteps | 18753    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 53.6     |
# |    ent_coef        | 1.25     |
# |    ent_coef_loss   | 0.0038   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16752    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 451      |
# | time/              |          |
# |    episodes        | 1008     |
# |    fps             | 77       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 19003    |
# | train/             |          |
# |    actor_loss      | -139     |
# |    critic_loss     | 51.5     |
# |    ent_coef        | 1.25     |
# |    ent_coef_loss   | -0.0165  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.3     |
# |    ep_rew_mean     | 505      |
# | time/              |          |
# |    episodes        | 1012     |
# |    fps             | 77       |
# |    time_elapsed    | 255      |
# |    total_timesteps | 19714    |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 42.8     |
# |    ent_coef        | 1.28     |
# |    ent_coef_loss   | -0.00546 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17712    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.1     |
# |    ep_rew_mean     | 512      |
# | time/              |          |
# |    episodes        | 1016     |
# |    fps             | 77       |
# |    time_elapsed    | 258      |
# |    total_timesteps | 19925    |
# | train/             |          |
# |    actor_loss      | -151     |
# |    critic_loss     | 52.9     |
# |    ent_coef        | 1.28     |
# |    ent_coef_loss   | -0.00965 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17924    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.3     |
# |    ep_rew_mean     | 514      |
# | time/              |          |
# |    episodes        | 1020     |
# |    fps             | 77       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 20092    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 50.3     |
# |    ent_coef        | 1.29     |
# |    ent_coef_loss   | 0.00617  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18088    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.6     |
# |    ep_rew_mean     | 583      |
# | time/              |          |
# |    episodes        | 1024     |
# |    fps             | 76       |
# |    time_elapsed    | 272      |
# |    total_timesteps | 21003    |
# | train/             |          |
# |    actor_loss      | -152     |
# |    critic_loss     | 49       |
# |    ent_coef        | 1.3      |
# |    ent_coef_loss   | -0.00267 |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.3     |
# |    ep_rew_mean     | 599      |
# | time/              |          |
# |    episodes        | 1028     |
# |    fps             | 76       |
# |    time_elapsed    | 277      |
# |    total_timesteps | 21339    |
# | train/             |          |
# |    actor_loss      | -155     |
# |    critic_loss     | 38.1     |
# |    ent_coef        | 1.31     |
# |    ent_coef_loss   | 0.0103   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19336    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.7     |
# |    ep_rew_mean     | 621      |
# | time/              |          |
# |    episodes        | 1032     |
# |    fps             | 76       |
# |    time_elapsed    | 283      |
# |    total_timesteps | 21747    |
# | train/             |          |
# |    actor_loss      | -158     |
# |    critic_loss     | 38.4     |
# |    ent_coef        | 1.32     |
# |    ent_coef_loss   | 0.00507  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19744    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.2     |
# |    ep_rew_mean     | 663      |
# | time/              |          |
# |    episodes        | 1036     |
# |    fps             | 76       |
# |    time_elapsed    | 292      |
# |    total_timesteps | 22374    |
# | train/             |          |
# |    actor_loss      | -158     |
# |    critic_loss     | 44.8     |
# |    ent_coef        | 1.34     |
# |    ent_coef_loss   | -0.0146  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20372    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84       |
# |    ep_rew_mean     | 773      |
# | time/              |          |
# |    episodes        | 1040     |
# |    fps             | 73       |
# |    time_elapsed    | 322      |
# |    total_timesteps | 23667    |
# | train/             |          |
# |    actor_loss      | -169     |
# |    critic_loss     | 46       |
# |    ent_coef        | 1.42     |
# |    ent_coef_loss   | -0.0158  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21664    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 981      |
# | time/              |          |
# |    episodes        | 1044     |
# |    fps             | 69       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 26112    |
# | train/             |          |
# |    actor_loss      | -185     |
# |    critic_loss     | 34.7     |
# |    ent_coef        | 1.66     |
# |    ent_coef_loss   | -0.0164  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24108    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 1048     |
# |    fps             | 70       |
# |    time_elapsed    | 402      |
# |    total_timesteps | 28248    |
# | train/             |          |
# |    actor_loss      | -209     |
# |    critic_loss     | 47.7     |
# |    ent_coef        | 1.91     |
# |    ent_coef_loss   | -0.0255  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26244    |
# ---------------------------------
# Training complete. Model saved. Training took 427.31 seconds.

# %%
trainer.plot_rewards()
model = SAC.load("sac_idp_model1")
trainer.generate_video(model, video_filename='sac_idp_video1.mp4')
# Out:
# Total reward: 9359.025985761315
#         <video width=600 controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %% [markdown]
# # Reflexiones Finales
#
# **Estudiante:** Tomas Acosta Bernal &mdash; **Codigo:** 202011237
#
# A continuacion se discuten las preguntas planteadas a la luz de los resultados obtenidos en los ambientes **InvertedPendulum** e **InvertedDoublePendulum** con **A2C sin ajustar**, **A2C ajustado** y **SAC**.
#
# ### Que algoritmo es mas robusto? A que puede deberse?
#
# **SAC** resulta mas robusto que A2C. Las razones principales son:
#
# 1. **Es off-policy:** usa un replay buffer y reutiliza las transiciones varias veces, lo que reduce la varianza de las actualizaciones y disminuye su sensibilidad a la inicializacion o a la semilla.
# 2. **Maximiza recompensa + entropia** (Haarnoja et al., 2018). El termino de entropia incentiva la exploracion estocastica y evita que la politica colapse demasiado pronto a un optimo local.
# 3. **Aprende automaticamente el coeficiente de temperatura** `alpha`, lo que reduce la necesidad de ajuste fino. En A2C, en cambio, la combinacion (`learning_rate`, `n_steps`, `ent_coef`) impacta fuertemente la estabilidad.
#
# A2C, al ser on-policy y entrenar con muy pocos pasos por actualizacion (`n_steps`), produce gradientes mas ruidosos y curvas de aprendizaje que oscilan mas, especialmente sin ajuste de hiperparametros.
#
# ### Que algoritmo es mas costoso computacionalmente? A que puede deberse?
#
# En **tiempo total para alcanzar una buena politica**, A2C resulta mas costoso porque necesita muchos mas pasos del ambiente (cientos de miles) para converger en estos problemas continuos, mientras que SAC alcanza recompensas comparables con un orden de magnitud menos de interacciones.
#
# En **costo por paso de entrenamiento**, sin embargo, SAC es mas caro: en cada interaccion realiza varias actualizaciones de gradiente sobre redes Q gemelas, una red de politica y un `alpha` aprendible, todo a partir del replay buffer. A2C en cambio solo hace una actualizacion cada `n_steps` interacciones.
#
# Resumen:
# - **A2C** &rarr; barato por paso, caro en numero de pasos. Se beneficia de GPU al usar entornos vectorizados.
# - **SAC** &rarr; caro por paso, muy eficiente en muestras. Corre mejor en CPU para redes pequenas porque la transferencia GPU domina el tiempo.
#
# ### Que algoritmo obtiene mejores resultados?
#
# En ambos ambientes (`InvertedPendulum` e `InvertedDoublePendulum`), **SAC alcanza recompensas mas altas y mas rapidamente** que A2C, aun usando del orden de 10x menos pasos de entrenamiento. Esto coincide con lo reportado en la literatura para tareas de control continuo de baja dimension.
#
# A2C ajustado mejora respecto a A2C por defecto, pero todavia queda por debajo del desempeno asintotico de SAC dentro del presupuesto de pasos utilizado.
#
# ### Resulto util el ajuste de hiperparametros?
#
# **Si.** Reducir `learning_rate` y aumentar `n_steps` en A2C produce una curva de aprendizaje mas estable y con menor varianza entre episodios; el agente alcanza politicas competentes con menos colapsos. En SAC, reducir la tasa de aprendizaje y aumentar `gradient_steps` y `train_freq` mejora la estabilidad final, aunque el efecto es menos dramatico que en A2C porque SAC ya es bastante robusto a hiperparametros por defecto.
#
# **Conclusion practica:** para tareas continuas de control con MuJoCo conviene preferir SAC cuando la prioridad es eficiencia muestral y estabilidad; A2C es razonable cuando se dispone de muchos entornos paralelos en GPU y se busca velocidad de *wall-clock* por iteracion.

# %% [markdown]
# # Referencias
#
# [1] Sutton, R. S. and Barto, A. G. (2018). Reinforcement Learning: An Introduction. The MIT Press, second edition.
#
# [2] Mnih, V., Puigdomènech, A., Mirza, M., Graves A., Lillicrap T., Harley, T., Silver, D. and Kavukcuoglu, K. (2016). Asynchronous Methods for Deep Reinforcement Learning. cite arXiv:1602.01783.
#
# [3] Haarnoja, T., Zhou, A., Abbeel, P. and Levine, S. (2018). Soft Actor-Critic: Off-Policy Maximum Entropy Deep Reinforcement Learning with a Stochastic Actor. cite arXiv:1801.01290.
#
# [4] Gym Documentation, Inverted Pendulum. `https://gymnasium.farama.org/environments/mujoco/inverted_pendulum/`
#
# [5] Gym Documentation, Inverted Double Pendulum. `https://gymnasium.farama.org/environments/mujoco/inverted_double_pendulum/`
#
# [6] Stable Baselines3 Documentation, A2C. `https://stable-baselines.readthedocs.io/en/master/modules/a2c.html`
#
# [7] Stable Baselines3 Documentation, SAC. `https://stable-baselines.readthedocs.io/en/master/modules/sac.html`
