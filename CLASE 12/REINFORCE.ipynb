# %% [markdown]
# # REINFORCE
#
# Este tutorial pretende introducir uno de los primeros algoritmos de gradiente de política: REINFORCE. Nuevamente, para ilustrar el funcionamiento y desempeño del algoritmo, se hará uso de un problema basado en un juego de Atari, donde el agente aprenderá directamente de las imágenes del juego. Al mismo tiempo, se profundizará en los beneficios que tiene la utilización de <i>baselines</i> durante el entrenamiento. Para ello, en este notebook se utiliza la librería Gymnasium, que incluye el juego de <i>Atlantis</i>, y una implementación de REINFORCE realizada para PyTorch.

# %% [markdown]
# # Marco Teórico
#
# Hasta ahora, los algoritmos de aprendizaje por refuerzo que se han explorado se basan en aprender y estimar una función de valor para cada acción, por lo que reciben el nombre de métodos de valor-acción (<i>action-value methods</i>). Es decir, las políticas aprendidas en estos métodos dependen directamente de los estimativos de la función de valor-acción ($Q(s,a)$). Sin embargo, existe otra familia de algoritmos que siguen un método de gradiente de política (<i>policy gradient methods</i>), que directamente aprenden una política parametrizada con la capacidad de seleccionar acciones sin la necesidad de estimar una función de valor. Una función de valor puede ser todavía utilizada para aprender el parámetro de la política, pero no se requiere para seleccionar la acción. [1]
#
# Por convención de notación, se utiliza $\theta$ para referirse a un vector de parámetros de la política. Entonces se puede escribir que la política, corresponde a la probabilidad de elegir una acción dado un estado y el vector de parámetros: $\pi(a|s,\theta) = Pr(A_t=a|S_t=s, \theta_t=\theta)$. La forma en que un algoritmo aprende y actualiza el vector de parámetros $\theta$ se basa en el gradiente de alguna métrica de desempeño escalar $J(\theta)$. Este método busca maximizar el desempeño, así que se tiene un ascenso de gradiente en $J$, como se muestra en la Ecuación (1). Se utiliza la notación $\widehat{\nabla J(\theta_t)}$ para denotar que el gradiente en realidad se calcula utilizando un estimativo estocástico. [1]
#
# $\theta_{t+1}=\theta + \alpha \widehat{\nabla J(\theta_t)}$ &emsp;&emsp;&emsp;$(1)$
#
# Otro elemento importante a tener en cuenta es el teorema de gradiente de política (policy gradient theorem), mostrado en la Ecuación (2). En este teorema, se establece que existe una proporcionalidad entre el gradiente de la función $J(\theta)$ y una expresión analítica dependiente de los parámetros de la política ($\theta$) y que se puede muestrear directamente a partir de la interacción con el ambiente a medida que se mejora la política.
# Esto en últimas permite encontrar la máxima dirección de crecimiento de $J(\theta)$ y ajustar los parámetros utilizando una constante de proporcionalidad $\alpha$ como se escribió en la Ecuación (1).
#
#  $\nabla J(\theta) \propto \sum_s \mu(s) \sum_a q_\pi(s, a) \nabla \pi(a|s, \theta)$ &emsp;&emsp;&emsp;$(2)$
#
# El algoritmo de REINFORCE, un algoritmo de gradiente de política, utiliza la regla de actualización de la Ecuación (3), estimando el gradiente estocástico utilizando el retorno $G_t$:
#
# $\theta_{t+1} \doteq \theta_t + \alpha G_t \frac{\nabla \pi(A_t | S_t, \theta_t)}{\pi(A_t | S_t, \theta_t)}$ &emsp;&emsp;&emsp;$(3)$
#
# En esta actualización, cada incremento es proporcional al producto del retorno $G_t$ y un vector: el gradiente de la probabilidad de escoger la acción tomada dividida por la probabilidad de escoger dicha acción. Este vector corresponde a la dirección en el espacio de parámetros en la cual crece mayormente la probabilidad de escoger la acción $A_t$ en futuras visitas al estado $S_t$. La actualización es proporcional al retorno $G_t$, favoreciendo las acciones que generan mayor recompensa a largo plazo, y es inversamente proporcional a la probabilidad de escoger la acción, no favoreciendo así incorrectamente a acciones que se eligen frecuentemente. Debido a que REINFORCE utiliza el retorno completo desde un tiempo $t$, que incluye todas las recompensas vistas hasta el final del episodio, se dice que entonces REINFORCE es también un método de Monte Carlo. [1]
#
# Finalmente, se consigue una variación de la regla de actualización de REINFORCE si se incluye un <i>baseline</i>, como muestra la Ecuación (4). Incluir un <i>baseline</i> no cambia el valor esperado de la actualización, pero sí puede tener un efecto significativo en la varianza del aprendizaje, reduciéndola significativamente y haciendo el entrenamiento más estable. Para el caso de un MDP, dicho <i>baseline</i> debería variar con el estado, por lo cual una selección típica es utilizar una función de valor de estado $\hat{v}(s,\text{w})$, donde $\text{w}$ es un vector de pesos aprendido por otro algoritmo de valor-acción. [1]
#
# $\theta_{t+1} \doteq \theta_t + \alpha (G_t-b(S_t)) \frac{\nabla \pi(A_t | S_t, \theta_t)}{\pi(A_t | S_t, \theta_t)}$ &emsp;&emsp;&emsp;$(4)$

# %% [markdown]
# # Instalación de Librerías
#
# En este tutorial se va a utilizar un juego de Atari 2600: <i>Atlantis</i>. Este videojuego hace parte de los ambientes de Atari de la librería Gymnasium. También se requiere instalar correctamente PyTorch para el uso de redes neuronales. Ejecute el siguiente bloque de código para instalar todas las librerías y herramientas necesarias.

# %%
#Importa estas librerías
import torch #Importa herramientas de PyTorch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import gymnasium #importa la libreria de gymnasium con las simulaciones
import renderlab #importa renderlab para los videos
import stable_baselines3 #importa Stable Baselines3
from stable_baselines3.common.env_util import make_atari_env #importa make_atari_env para escala de grises
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack #importa VecFrameStack para apilar frames y acelerar así el entrenamiento
import ale_py #importa ale para los ambientes de Atari
from gymnasium.wrappers import TimeLimit #importa timelimit para acortar los episodios
from collections import deque #importa para ajustar los videos con VecFrameStack
import cv2 #importa para ajustar los videos con VecFrameStack

#!Importante:
gymnasium.register_envs(ale_py) #Hay que registrar los entornos de ALE manualmente!!!

#Importa otras librerías básicas
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import pandas as pd
import sys
import argparse
from itertools import count

#Limpia los registros generados
from IPython.display import clear_output
clear_output()
print("Todas las librerías han sido instaladas correctamente.")
# Out:
# Todas las librerías han sido instaladas correctamente.

# %% [markdown]
# # Familiarización con el Entorno de Gym

# %% [markdown]
# En esta oportunidad, trabajaremos con el entorno de <i>Atlantis</i> [2]. En este juego de Atari, la ciudad submarina de Atlantis está siendo atacada por aviones y otras aeronaves; el jugador debe usar una serie de torretas para derribar estas aeronaves antes de que logren destruir por completo la ciudad.
# Una captura de cómo se ve el juego se muestra en la Figura 3.
#
#
# ![freeway](https://raw.githubusercontent.com/MAIA4361-Aprendizaje-refuerzo-profundo/Notebooks_Tareas/main/Images/atlantis.png)
#
# <center>Figura 1. Ejemplo de una partida de <i>Atlantis</i>.</center>
#
# En este ambiente el jugador tiene 4 posibles acciones en cada paso de tiempo:
#
# *   0 - No hace nada (NOOP).
# *   1 - Dispara la torreta central (FIRE).
# *   2 - Dispara la torreta de la derecha (RIGHTFIRE).
# *   3 - Dispara la torreta de la izquierda (LEFTFIRE).
#
# Normalmente, cuando el jugador logra asestar un disparo a una aeronave recibe 100 o 200 puntos. También el jugador comienza a recibir puntos después de cierto tiempo por sobrevivir. En este ambiente se puede también configurar el modo de juego (mode) con un número entre 0 y 3, modificando la cantidad de aeronaves y su velocidad, mientras que la única dificultad (difficulty) disponible 0.

# %% [markdown]
# ## Ejemplo
#
# En este ejemplo se muestra cómo simular una partida de <i>Atlantis</i> dentro de Google Colab. Para este ejemplo se usa el modo 0 de juego, y en cada paso de tiempo se hace una selección aleatoria entre las 4 acciones disponibles.

# %%
#Parámetros del ambiente
env_render = gymnasium.make("ALE/Atlantis-v5", render_mode="rgb_array", mode=0, difficulty=0) #Se crea el ambiente.
env_render = renderlab.RenderFrame(env_render, "./output") #Se crea una copia que se pueda renderizar con renderlab

terminated = False #Inicializa una condición para el loop
truncated = False #Inicializa una condición para el loop
total_reward=0 #Inicializa contador del retorno

obs , info = env_render.reset() #Se reinicia el estado para comenzar. En obs se almacena el estado observado
while not (terminated or truncated): #Simula hasta que termine la partida
  action = random.choice([0, 1, 2, 3])  # Elige una acción aleatoria
  obs, reward, terminated, truncated, info = env_render.step(action) #Da el paso
  total_reward += reward #Suma recompensa

print("Recompensa obtenida en el episodio:",total_reward) #Se imprime la recompensa obtenida
print("\n\n")

env_render.play() #Con esta función se obtiene el video de la simulación
# Out:
# Recompensa obtenida en el episodio: 7200.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# En la simulación se puede observar que una política uniformemente aleatoria obtendrá, por lo general, una puntuación cercana a 10,000 puntos antes de perder. Con esta referencia se pueden comparar el resto de políticas que se obtengan en el tutorial utilizando el algoritmo de REINFORCE.

# %% [markdown]
# ## Ejercicio Práctico
#
# Antes de continuar, puede intentar simular una partida utilizando los modos de juego 1, 2 o 3, manteniendo la aleatoriedad de acciones para comprobar el correcto entendimiento del ambiente.

# %%
# Ejecute una partida con modo 1, 2 o 3

# =====================================================
# Simulacion con modo de juego distinto al 0 (politica aleatoria)
# Cambiar la variable game_mode a 1, 2 o 3 para probar otros modos.
game_mode = 2

env_render = gymnasium.make("ALE/Atlantis-v5", render_mode="rgb_array", mode=game_mode, difficulty=0)
env_render = renderlab.RenderFrame(env_render, "./output")

terminated = False
truncated = False
total_reward = 0

obs, info = env_render.reset()
while not (terminated or truncated):
    action = random.choice([0, 1, 2, 3])  # Politica uniformemente aleatoria
    obs, reward, terminated, truncated, info = env_render.step(action)
    total_reward += reward

print("Modo de juego:", game_mode)
print("Recompensa obtenida en el episodio:", total_reward)
print("\n\n")

env_render.play()
# =====================================================
# Out:
# Modo de juego: 2
# Recompensa obtenida en el episodio: 13900.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # REINFORCE
#
# En el siguiente bloque de código se suministra una implementación del algoritmo de REINFORCE basada en un ejemplo oficial encontrado en el repositorio de PyTorch [3], originalmente programado para resolver el ambiente de <i>Cart Pole</i>. En esta versión, se utiliza una red neuronal convolucional de 3 capas para aprender a partir de las imágenes del ambiente de Atari. Para agilizar el aprendizaje, dichas imágenes se reescalan a un tamaño de 84x84 y se colocan en escala de grises, y se aplica un framestack de 2 frames para captar información de movimiento. Es importante mencionar que en esta clase se pueden personalizar los siguientes hiperparámetros del algoritmo:
#
#
# *   `use_baseline`: Parámetro que puede tomar como valor un número entero entre 0 y 3. Este es el parámetro más importante para este tutorial, ya que cambia la configuración de <i>baseline</i> utilizado para el algoritmo. Un valor de 0 indica que no se usa ningún <i>baseline</i> (valor por defecto); un valor de 1 hace que se aplique una normalización de la recompensa y los retornos que reduce la varianza, aunque no es un <i>baseline</i> como tal, debería tener el mismo efecto; un valor de 2 usa como <i>baseline</i> el promedio de los retornos vistos anteriormente, lo cual es una métrica sencilla de calcular, pero es poco recomendada y puede no ser útil; y finalmente un valor de 3 utiliza una segunda red neuronal para estimar la función de valor en cada estado $V(s)$.
# *   `learning_rate_reinforce`: Tasa de aprendizaje del algoritmo de REINFORCE (por defecto en `1e-5`).
# *   `learning_rate_baseline`: Tasa de aprendizaje para la red neuronal que aproxima la función de valor, cuando se utiliza `use_baseline=3` (por defecto en `1e-6`)
# *   `gamma`: Factor de descuento (por defecto en `1`).
# *   `max_steps_per_episode`: Cantidad máxima de pasos que puede pasar el agente en un episodio, evitando la posibilidad de partidas infinitas (por defecto en `5000`).
# *   `max_training_episodes`: Cantidad máxima de episodios por los que puede entrenar el algoritmo (por defecto en `1500`).

# %%
"""
Adaptado del ejemplo de PyTorch encontrado en https://github.com/pytorch/examples/blob/main/reinforcement_learning/reinforce.py
"""

class Policy_atla(nn.Module):
  """Esta clase define la red neuronal usada para el juego de Atlantis"""
  def __init__(self):
    super(Policy_atla, self).__init__()
    #Crea una red convolucional de 3 capas.
    #Entrada: 2 frames en escala de grises de tamaño 84x84
    #Salida: Distribución de probabilidad sobre 4 acciones posibles
    self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
    self.bn1 = nn.BatchNorm2d(32)
    self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
    self.bn2 = nn.BatchNorm2d(64)
    self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
    self.bn3 = nn.BatchNorm2d(64)
    self.fc1 = nn.Linear(64 * 7 * 7, 512)
    self.fc2 = nn.Linear(512, 4)
    self.saved_log_probs = []
    self.rewards = []
  def forward(self, x):
    #Flujo de la red neuronal
    #Aplica una función SOFTMAX en la salida para retornar probabilidades
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x))
    x = x.reshape(x.size(0), -1)
    x = F.relu(self.fc1(x))
    return F.softmax(self.fc2(x), dim=1)

class ValueNetwork(nn.Module):
  """Esta clase define la red neuronal usada para la estimación de la función de valor (baseline)"""
  def __init__(self):
    #Crea una red convolucional de 3 capas.
    #Entrada: 2 frames en escala de grises de tamaño 84x84
    #Salida: Éstimación de la función de valor en el estado
    super(ValueNetwork, self).__init__()
    self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
    self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
    self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
    self.fc1 = nn.Linear(64 * 7 * 7, 512)
    self.fc2 = nn.Linear(512, 1)
  def forward(self, x):
    #Flujo de la red neuronal
    #Retorna un solo valor escalar que representa el valor esperado del estado actual
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x))
    x = x.reshape(x.size(0), -1)
    x = F.relu(self.fc1(x))
    return self.fc2(x).squeeze(-1)

class REINFORCE_atla:
  """Esta clase inicializa el agente, lo entrena y realiza una validación"""
  def __init__(self, use_baseline=0, learning_rate_reinforce=1e-5, learning_rate_baseline=1e-6, gamma=1, max_steps_per_episode=5000, max_training_episodes=1500):
    #INPUTS:
    #use_baseline: Indica si usar o no baseline y qué baseline usar
    #(0: No usar Baseline, 1: Usar normalización de recompensas, 2: Usar promedio de recompensas como baseline, 3: Usar función de valor como baseline)
    #learning_rate_reinforce: Tasa de aprendizaje del algoritmo de Reinforce
    #learning_rate_baseline: Tasa de aprendizaje para el estimador de la función de valor
    #gamma: factor de descuento
    #max_steps_per_episode: Máxima duración de un episodio
    #max_training_episodes: Cantidad máxima de episodios para entrenar

    #Algunos parámetros
    self.gamma=gamma
    self.seed=543
    self.log_interval=20 #Cada cuántos episodios se imprime un logger en pantalla
    self.max_steps_per_episode=max_steps_per_episode #Cantidad máxima de pasos por episodio (limitar duración)
    self.max_training_episodes=max_training_episodes #Cantidad máxima de episodios para entrenamiento (limitar duración)
    self.use_baseline=use_baseline #Usar o no baseline y de qué tipo (0, 1, 2 o 3)

    #Selecciona dispositivo (GPU si esta disponible)
    self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"[REINFORCE_atla] Usando dispositivo: {self.device}"
          + (f" ({torch.cuda.get_device_name(0)})" if self.device.type == 'cuda' else ""))

    #Crea el ambiente con escala de grises y apilando 2 frames
    self.env = make_atari_env("ALE/Atlantis-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 0})
    self.env = VecFrameStack(self.env, n_stack=2)

    #Inicializa ambiente
    obs = self.env.reset()
    torch.manual_seed(self.seed)

    #Inicializa variables para almacenar estados/datos
    self.last_state = obs
    self.last_states = []
    self.all_episodes_rewards = []

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    #Inicializa la política (red neuronal) y la mueve al dispositivo
    self.policy = Policy_atla().to(self.device)
    self.optimizer = optim.Adam(self.policy.parameters(), lr=learning_rate_reinforce)  # learning_Rate más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()

    #Inicializa el estimador de la función de valor (red neuronal, si se usa use_baseline=3)
    self.value_function_estimator = ValueNetwork().to(self.device)
    self.value_function_estimator_optimizer = optim.Adam(self.value_function_estimator.parameters(), lr=learning_rate_baseline)


  def select_action(self, state, epsilon=0.15):
    #Esta función selecciona una acción en cada paso de la simulación
    #INPUTS:
    #state: el estado correspondiente a la observación del ambiente (framestack de 2 frames)
    #epsilon: una tasa de exploración adicional

    #Convierte la imagen en un tensor de PyTorch. Dimension original: (1, 84, 84, 2)
    state = torch.from_numpy(state).float().to(self.device)
    state = state.permute(0, 3, 1, 2)  #Dimension final: (1, 2, 84, 84)

    if random.random() < epsilon:  # Con probabilidad epsilon, se elige acción aleatoria
      action = random.choice([0, 1, 2, 3])
    else:
      #La red neuronal elige una acción
      probs = self.policy(state)
      m = Categorical(probs)
      action = m.sample()
      self.policy.saved_log_probs.append(m.log_prob(action))
      action = action.item()

    #Guarda estados para uso de baseline
    self.last_state = state
    self.last_states.append(state)

    return action #Retorna la acción escogida (0, 1, 2 o 3)


  def finish_episode(self):
    #Al final de cada episodio hace una actualización de la política (Monte Carlo)

    #Inicializa valores
    R = 0
    policy_loss = []
    returns = deque()

    #Obtiene el retorno con todas las recompensas del episodio teniendo en cuenta el factor de descuento
    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)
    returns = torch.tensor(returns, dtype=torch.float32, device=self.device)

    #Caso de Baseline
    if(self.use_baseline==3): #Si use_baseline==3, usa la aproximación de función de valor
      state_batch = torch.cat(self.last_states, dim=0)
      value_preds = self.value_function_estimator(state_batch).squeeze().detach()
      advantages = returns - value_preds
    elif(self.use_baseline==2): #Si use_baseline==2, usa un promedio de los retornos vistos
      advantages = returns - returns.mean()
    elif(self.use_baseline==1): #Si use_baseline==1, sólo aplica una normalización del retorno
      if len(returns) > 1 and returns.std() > 1e-6:
        returns = (returns - returns.mean()) / (returns.std() + self.eps)
      else:
        returns = returns - returns.mean()
      advantages = returns
    else: #En cualquier otro caso (#Si use_baseline==0), no usa baseline
      advantages = returns

    #Cálculo de pérdida de la política
    for log_prob, advantage in zip(self.policy.saved_log_probs, advantages):
        if log_prob is not None:
            policy_loss.append(-log_prob * advantage)

    #Retropropagación de la red neuronal
    self.optimizer.zero_grad()
    if len(policy_loss) == 0:
        return
    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()

    #Si use_baseline==3, también actualiza la red neuronal que estima la función de valor
    if(self.use_baseline==3):
      self.value_function_estimator_optimizer.zero_grad()
      predicted_values = self.value_function_estimator(state_batch).squeeze()
      value_function_estimator_loss = F.mse_loss(predicted_values, returns)
      value_function_estimator_loss.backward()
      self.value_function_estimator_optimizer.step()

    #Limpia las variables temporales (siempre, no solo cuando use_baseline==3)
    self.last_states.clear()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]


  def train(self):
    #Esta función ejecuta todo el entrenamiento

    #Inicializa variables
    running_reward = 0
    cumulative_episodes_reward=0

    for i_episode in range(1,self.max_training_episodes+1): #Ejecuta como máximo max_steps_per_episode para que el entrenamiento no sea infinito
        #Inicializa el ambiente y la recompensa total del episodio
        state = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  #Cada episodio tiene un máximo de pasos para que no pueda quedarse hasta el infinito
          action = self.select_action(state, epsilon=0) #Elige acción
          state, reward, done, _ = self.env.step([action])
          self.policy.rewards.append(reward[0]) #Almacena recompensa para actualizaciones
          ep_reward += np.array(reward).item()
          if done: #Si pierde, termina el episodio
            break

        #Después de terminar el episodio, calcula running_reward, y actualiza variables para el promedio y grafica
        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        cumulative_episodes_reward += ep_reward

        self.finish_episode()

        #Imprime estadísticas en pantalla
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tLast 20 Episodes Average Reward: {:.2f}\t\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward*100, cumulative_episodes_reward*100/20, running_reward*100)) #Las recompensas están divididas por 100 en el ambiente
          self.all_episodes_rewards.append(cumulative_episodes_reward*100/20)
          cumulative_episodes_reward=0
        #Cuando running_reward pasa un umbral da por terminado el entrenamiento
        if running_reward > 5:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward*100, t))
          break

  def graph_training(self):
    # Esta función realiza una gráfica de la recompensa cada 20 episodios
    interval = 20  # Intervalo entre muestras
    episodes = [i * interval for i in range(1, len(self.all_episodes_rewards) + 1)]

    plt.figure(figsize=(10, 5))
    plt.plot(episodes, self.all_episodes_rewards, color='orange', marker='o')
    plt.xlabel('Episodio')
    plt.ylabel('Recompensa total')
    plt.title('Curva de aprendizaje: Recompensa promedio de cada 20 episodios')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

  def video(self):
    #Crea un entorno para renderizar
    env = gymnasium.make("ALE/Atlantis-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    #Frame stack manual para el modelo, para que el video no salga cortado (se apilan dos frame, en escala de gris, tamano 84x84)
    frame_stack = deque(maxlen=2)

    #Reset inicial
    obs, info = env.reset()

    #Procesa una copia del frame solo para el modelo
    def preprocess(obs):
      gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
      resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA) #redimensiona
      return resized

    #Realiza el framestack
    preprocessed = preprocess(obs)
    for _ in range(2):
      frame_stack.append(preprocessed)

    #Inicialización del ambiente
    terminated = False
    truncated = False
    total_reward = 0

    #Loop de simulacion
    while not (terminated or truncated):
        #Convierte frames a la forma (2, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)

        #Cambia el orden de las dimensiones a (1, 2, 84, 84) (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 2, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 2)

        #Elige la accion (select_action mueve internamente el tensor a self.device)
        action=self.select_action(stacked_obs, epsilon=0) #especifica que no hay exploracion

        #Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        #Actualiza el stack solo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    #Muestra la recompensa total obtenida y el video
    print("\n\n")
    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()

# %% [markdown]
# ## Ejemplo de Uso
#
# Para utilizar ese código, simplemente debe:
#
# 1.   Crear el agente.
# 2.   Entrenar el algoritmo.
# 3.   Mostrar la curva de aprendizaje (opcional).
# 4.   Mostrar el video de validación de la política aprendida.
# 5.   Guardar la política como archivo (recomendado, descargar de los archivos Colab).
#
# A continuación, se muestra un ejemplo de uso para el caso `use_baseline=0`, es decir, un entrenamiento sin usar <i>baselines</i>. Puede reutilizar este bloque de código para los ejercicios posteriores.

# %%
# Ejemplo: Entrenamiento de REINFORCE sin baselines
print("Entrenamiento SIN baseline.")
print("\n")
agente_atlantis0=REINFORCE_atla(use_baseline=0,max_steps_per_episode=5000, max_training_episodes=1500) #Inicializa agente
agente_atlantis0.train() #Entrena
agente_atlantis0.graph_training() #Grafica curva de aprendizaje
agente_atlantis0.video() #Validación en video
torch.save(agente_atlantis0.policy.state_dict(), 'policy_agente0.pth') #Salva la politica
# Out:
# Entrenamiento SIN baseline.
#
#
# [REINFORCE_atla] Usando dispositivo: cuda (NVIDIA GeForce RTX 4060 Laptop GPU)
# Episode 20 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 90.00		Running reward: 56.69
# Episode 40 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 80.00		Running reward: 73.62
# Episode 60 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 190.00		Running reward: 123.09
# Episode 80 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 205.00		Running reward: 172.91
# Episode 100 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 115.00		Running reward: 127.10
# Episode 120 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 135.00		Running reward: 141.02
# Episode 140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 105.00		Running reward: 113.81
# Episode 160 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 145.00		Running reward: 142.25
# Episode 180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 162.66
# Episode 200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 167.14
# Episode 220 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 100.00		Running reward: 123.12
# Episode 240 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 195.00		Running reward: 153.67
# Episode 260 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 220.00		Running reward: 198.48
# Episode 280 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 130.00		Running reward: 152.13
# Episode 300 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 60.00		Running reward: 96.71
# Episode 320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 140.00		Running reward: 117.39
# Episode 340 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 140.00		Running reward: 137.25
# Episode 360 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 140.00		Running reward: 143.79
# Episode 380 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 121.62
# Episode 400 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 145.00		Running reward: 135.36
# Episode 420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 129.06
# Episode 440 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 165.00		Running reward: 160.24
# Episode 460 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 195.00		Running reward: 168.84
# Episode 480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 140.00		Running reward: 160.93
# Episode 500 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 255.00		Running reward: 215.83
# Episode 520 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 65.00		Running reward: 112.80
# Episode 540 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 50.00		Running reward: 75.59
# Episode 560 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 50.00		Running reward: 60.08
# Episode 580 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 25.00		Running reward: 37.89
# Episode 600 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 55.00		Running reward: 48.81
# Episode 620 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 95.00		Running reward: 83.33
# Episode 640 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 105.00		Running reward: 94.05
# Episode 660 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 104.04
# Episode 680 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 105.00		Running reward: 112.36
# Episode 700 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 185.00		Running reward: 179.60
# Episode 720 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 80.00		Running reward: 119.90
# Episode 740 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 95.00		Running reward: 107.00
# Episode 760 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 95.00		Running reward: 106.13
# Episode 780 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 125.00		Running reward: 118.32
# Episode 800 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 127.06
# Episode 820 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 180.00		Running reward: 160.15
# Episode 840 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 70.00		Running reward: 102.86
# Episode 860 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 220.00		Running reward: 193.69
# Episode 880 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 205.00		Running reward: 220.40
# Episode 900 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 199.11
# Episode 920 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 80.00		Running reward: 129.11
# Episode 940 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 101.04
# Episode 960 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 121.38
# Episode 980 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 120.00		Running reward: 117.88
# Episode 1000 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 135.00		Running reward: 129.96
# Episode 1020 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 195.00		Running reward: 166.84
# Episode 1040 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 295.00		Running reward: 219.16
# Episode 1060 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 145.00		Running reward: 172.21
# Episode 1080 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 123.43
# Episode 1100 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 156.31
# Episode 1120 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 125.76
# Episode 1140 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 205.00		Running reward: 179.09
# Episode 1160 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 240.00		Running reward: 215.71
# Episode 1180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 105.00		Running reward: 144.82
# Episode 1200 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 130.00		Running reward: 144.68
# Episode 1220 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 290.00		Running reward: 226.28
# Episode 1240 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 150.00		Running reward: 179.55
# Episode 1260 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 198.34
# Episode 1280 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 240.00		Running reward: 231.11
# Episode 1300 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 220.00		Running reward: 230.48
# Episode 1320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 310.00		Running reward: 295.23
# Episode 1340 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 330.00		Running reward: 296.80
# Episode 1360 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 75.00		Running reward: 160.77
# Episode 1380 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 145.00		Running reward: 146.80
# Episode 1400 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 155.05
# Episode 1420 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 305.00		Running reward: 254.31
# Episode 1440 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 205.00		Running reward: 224.33
# Episode 1460 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 245.00		Running reward: 227.56
# Episode 1480 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 205.00		Running reward: 208.15
# Episode 1500 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 235.00		Running reward: 209.90
# Recompensa obtenida en el episodio: 30600.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Ejercicio Práctico
#
# En el anterior ejemplo se puede observar una recompensa en el video cercana a 12,000 puntos. Este puntaje es objetivamente bajo si se compara con el puntaje de 10,000 obtenido utilizando una política aleatoria. Esto muestra cómo entrenar sin <i>baselines</i> puede no ser efectivo, y en este ejercicio se busca explorar las otras alternativas, comparar los resultados obtenidos y reflexionar sobre los mismos. Se propone:
#
#
# *   Realice el mismo entrenamiento utilizando normalización de recompensas (`use_baseline=1`).
# *   Realice el mismo entrenamiento utilizando un promedio de los retornos obtenidos como <i>baseline</i> (`use_baseline=2`).
# *   Realice el mismo entrenamiento utilizando una segunda red neuronal para estimar la función de valor de los estados (`use_baseline=3`).
#
# Cada uno de estos entrenamientos debería tomar aproximadamente 10 minutos. Se recomienda salvar los entrenamientos realizados y vigilar que no se sature la RAM de Google Colab.
#
# Adicionalmente, puede probar modificando los parámetros de tasa de aprendizaje, a los cuales el algoritmo de REINFORCE es más sensible:
#
# *   `learning_rate_reinforce` entre `1e-3` y `1e-6`.
# *   `learning_rate_baseline` entre `1e-4` y `1e-6`.

# %%
# Entrenamiento de REINFORCE sin baselines pero con noramlizacion de recompensas (use_baseline=1)

# =====================================================
print("Entrenamiento CON normalizacion de recompensas (use_baseline=1).")
print("\n")

agente_atlantis1 = REINFORCE_atla(
    use_baseline=1,
    learning_rate_reinforce=1e-5,
    learning_rate_baseline=1e-6,
    gamma=1,
    max_steps_per_episode=5000,
    max_training_episodes=1500,
)

agente_atlantis1.train()           # Entrena
agente_atlantis1.graph_training()  # Grafica curva de aprendizaje
agente_atlantis1.video()           # Validacion en video

# Salva la politica entrenada
torch.save(agente_atlantis1.policy.state_dict(), 'policy_agente1.pth')
# =====================================================
# Out:
# Entrenamiento CON normalizacion de recompensas (use_baseline=1).
#
#
# [REINFORCE_atla] Usando dispositivo: cuda (NVIDIA GeForce RTX 4060 Laptop GPU)
# Episode 20 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 85.00		Running reward: 53.69
# Episode 40 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 91.24
# Episode 60 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 215.00		Running reward: 166.82
# Episode 80 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 140.00		Running reward: 155.54
# Episode 100 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 220.00		Running reward: 193.74
# Episode 120 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 95.00		Running reward: 130.53
# Episode 140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 116.54
# Episode 160 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 155.00		Running reward: 145.75
# Episode 180 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 195.00		Running reward: 166.91
# Episode 200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 117.55
# Episode 220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 114.50
# Episode 240 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 165.00		Running reward: 151.04
# Episode 260 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 140.00		Running reward: 154.02
# Episode 280 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 115.00		Running reward: 127.34
# Episode 300 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 160.00		Running reward: 154.09
# Episode 320 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 210.00		Running reward: 200.33
# Episode 340 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 125.00		Running reward: 144.05
# Episode 360 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 185.00		Running reward: 166.67
# Episode 380 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 110.00		Running reward: 131.33
# Episode 400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 119.96
# Episode 420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 158.40
# Episode 440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 165.00		Running reward: 161.65
# Episode 460 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 230.00		Running reward: 219.47
# Episode 480 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 175.00		Running reward: 187.01
# Episode 500 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 145.00		Running reward: 169.03
# Episode 520 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 176.16
# Episode 540 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 155.00		Running reward: 165.98
# Episode 560 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 60.00		Running reward: 102.76
# Episode 580 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 97.65
# Episode 600 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 105.00		Running reward: 97.67
# Episode 620 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 152.40
# Episode 640 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 137.45
# Episode 660 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 126.90
# Episode 680 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 138.14
# Episode 700 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 163.24
# Episode 720 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 172.16
# Episode 740 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 210.00		Running reward: 181.48
# Episode 760 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 180.00		Running reward: 180.76
# Episode 780 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 205.00		Running reward: 179.37
# Episode 800 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 180.00		Running reward: 192.04
# Episode 820 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 145.00		Running reward: 175.48
# Episode 840 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 205.00		Running reward: 201.01
# Episode 860 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 145.00		Running reward: 158.17
# Episode 880 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 115.00		Running reward: 122.31
# Episode 900 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 130.00		Running reward: 121.65
# Episode 920 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 130.00		Running reward: 119.54
# Episode 940 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 145.00		Running reward: 125.45
# Episode 960 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 152.36
# Episode 980 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 129.48
# Episode 1000 completed.	Last Reward: 700.00	Last 20 Episodes Average Reward: 255.00		Running reward: 205.47
# Episode 1020 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 175.00		Running reward: 177.99
# Episode 1040 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 200.00		Running reward: 190.54
# Episode 1060 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 165.00		Running reward: 173.23
# Episode 1080 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 210.00		Running reward: 217.41
# Episode 1100 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 250.00		Running reward: 245.43
# Episode 1120 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 193.86
# Episode 1140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 155.00		Running reward: 172.32
# Episode 1160 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 180.00		Running reward: 192.65
# Episode 1180 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 220.00		Running reward: 204.44
# Episode 1200 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 115.00		Running reward: 144.38
# Episode 1220 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 170.00		Running reward: 154.57
# Episode 1240 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 270.00		Running reward: 227.97
# Episode 1260 completed.	Last Reward: 900.00	Last 20 Episodes Average Reward: 270.00		Running reward: 273.03
# Episode 1280 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 225.00		Running reward: 240.67
# Episode 1300 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 305.00		Running reward: 268.52
# Episode 1320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 188.01
# Episode 1340 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 125.00		Running reward: 146.82
# Episode 1360 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 100.00		Running reward: 122.34
# Episode 1380 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 135.00		Running reward: 134.00
# Episode 1400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 255.00		Running reward: 216.17
# Episode 1420 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 205.00		Running reward: 207.05
# Episode 1440 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 168.57
# Episode 1460 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 175.00		Running reward: 162.67
# Episode 1480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 167.80
# Episode 1500 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 295.00		Running reward: 258.51
# Recompensa obtenida en el episodio: 23800.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Entrenamiento de REINFORCE con baseline como el promedio de los retornos (use_baseline=2)

# =====================================================
print("Entrenamiento CON baseline = promedio de retornos (use_baseline=2).")
print("\n")

agente_atlantis2 = REINFORCE_atla(
    use_baseline=2,
    learning_rate_reinforce=1e-5,
    learning_rate_baseline=1e-6,
    gamma=1,
    max_steps_per_episode=5000,
    max_training_episodes=1500,
)

agente_atlantis2.train()           # Entrena
agente_atlantis2.graph_training()  # Grafica curva de aprendizaje
agente_atlantis2.video()           # Validacion en video

# Salva la politica entrenada
torch.save(agente_atlantis2.policy.state_dict(), 'policy_agente2.pth')
# =====================================================
# Out:
# Entrenamiento CON baseline = promedio de retornos (use_baseline=2).
#
#
# [REINFORCE_atla] Usando dispositivo: cuda (NVIDIA GeForce RTX 4060 Laptop GPU)
# Episode 20 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 85.00		Running reward: 53.69
# Episode 40 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 85.00		Running reward: 73.51
# Episode 60 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 65.00		Running reward: 71.46
# Episode 80 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 60.00		Running reward: 57.28
# Episode 100 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 35.00		Running reward: 41.27
# Episode 120 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 50.00		Running reward: 43.95
# Episode 140 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 105.00		Running reward: 92.46
# Episode 160 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 130.00		Running reward: 103.12
# Episode 180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 195.00		Running reward: 157.67
# Episode 200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 80.00		Running reward: 112.18
# Episode 220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 108.94
# Episode 240 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 138.89
# Episode 260 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 120.00		Running reward: 131.98
# Episode 280 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 105.00		Running reward: 114.27
# Episode 300 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 123.06
# Episode 320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 245.00		Running reward: 191.54
# Episode 340 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 130.00		Running reward: 153.14
# Episode 360 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 180.00		Running reward: 186.85
# Episode 380 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 130.00		Running reward: 153.96
# Episode 400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 200.00		Running reward: 186.69
# Episode 420 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 220.00		Running reward: 206.49
# Episode 440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 153.70
# Episode 460 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 120.00		Running reward: 124.71
# Episode 480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 108.18
# Episode 500 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 190.00		Running reward: 144.80
# Episode 520 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 205.00		Running reward: 190.43
# Episode 540 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 152.56
# Episode 560 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 280.00		Running reward: 252.46
# Episode 580 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 180.00		Running reward: 200.40
# Episode 600 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 165.00		Running reward: 177.32
# Episode 620 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 185.00		Running reward: 181.80
# Episode 640 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 149.10
# Episode 660 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 160.00		Running reward: 162.02
# Episode 680 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 200.00		Running reward: 194.86
# Episode 700 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 170.00		Running reward: 179.04
# Episode 720 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 180.00		Running reward: 184.90
# Episode 740 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 173.50
# Episode 760 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 200.08
# Episode 780 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 164.55
# Episode 800 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 60.00		Running reward: 103.33
# Episode 820 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 105.00		Running reward: 100.84
# Episode 840 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 142.18
# Episode 860 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 119.40
# Episode 880 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 220.00		Running reward: 158.21
# Episode 900 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 135.00		Running reward: 138.87
# Episode 920 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 150.00		Running reward: 146.57
# Episode 940 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 230.00		Running reward: 194.12
# Episode 960 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 159.89
# Episode 980 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 295.00		Running reward: 246.74
# Episode 1000 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 105.00		Running reward: 157.53
# Episode 1020 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 185.00		Running reward: 193.38
# Episode 1040 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 140.00		Running reward: 164.14
# Episode 1060 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 145.04
# Episode 1080 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 260.00		Running reward: 191.21
# Episode 1100 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 50.00		Running reward: 103.55
# Episode 1120 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 75.00		Running reward: 86.10
# Episode 1140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 50.00		Running reward: 59.03
# Episode 1160 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 65.00		Running reward: 64.73
# Episode 1180 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 50.00		Running reward: 55.00
# Episode 1200 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 70.00		Running reward: 66.42
# Episode 1220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 65.00		Running reward: 62.83
# Episode 1240 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 85.00		Running reward: 72.04
# Episode 1260 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 55.00		Running reward: 61.09
# Episode 1280 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 85.00		Running reward: 74.82
# Episode 1300 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 80.00		Running reward: 74.93
# Episode 1320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 65.00		Running reward: 72.29
# Episode 1340 completed.	Last Reward: 1100.00	Last 20 Episodes Average Reward: 230.00		Running reward: 188.94
# Episode 1360 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 70.00		Running reward: 108.82
# Episode 1380 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 65.00		Running reward: 83.90
# Episode 1400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 80.00		Running reward: 77.57
# Episode 1420 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 55.00		Running reward: 66.33
# Episode 1440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 73.98
# Episode 1460 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 88.67
# Episode 1480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 107.56
# Episode 1500 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 80.00		Running reward: 89.36
# Recompensa obtenida en el episodio: 23500.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Entrenamiento de REINFORCE con baseline como estimación de la función de valor (use_baseline=3)

# =====================================================
print("Entrenamiento CON baseline = red neuronal V(s) (use_baseline=3).")
print("\n")

agente_atlantis3 = REINFORCE_atla(
    use_baseline=3,
    learning_rate_reinforce=1e-5,
    learning_rate_baseline=1e-6,
    gamma=1,
    max_steps_per_episode=5000,
    max_training_episodes=1500,
)

agente_atlantis3.train()           # Entrena (actualiza tambien la red de valor)
agente_atlantis3.graph_training()  # Grafica curva de aprendizaje
agente_atlantis3.video()           # Validacion en video

# Salva la politica y la red de valor entrenadas
torch.save(agente_atlantis3.policy.state_dict(), 'policy_agente3.pth')
torch.save(agente_atlantis3.value_function_estimator.state_dict(), 'value_agente3.pth')
# =====================================================
# Out:
# Entrenamiento CON baseline = red neuronal V(s) (use_baseline=3).
#
#
# [REINFORCE_atla] Usando dispositivo: cuda (NVIDIA GeForce RTX 4060 Laptop GPU)
# Episode 20 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 90.00		Running reward: 56.69
# Episode 40 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 80.00		Running reward: 73.62
# Episode 60 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 129.09
# Episode 80 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 165.00		Running reward: 150.02
# Episode 100 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 150.00		Running reward: 163.65
# Episode 120 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 115.00		Running reward: 139.12
# Episode 140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 155.03
# Episode 160 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 55.00		Running reward: 94.79
# Episode 180 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 70.00		Running reward: 83.15
# Episode 200 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 180.00		Running reward: 143.67
# Episode 220 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 130.00		Running reward: 135.08
# Episode 240 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 145.00		Running reward: 149.61
# Episode 260 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 135.00		Running reward: 145.08
# Episode 280 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 170.00		Running reward: 165.56
# Episode 300 completed.	Last Reward: 1000.00	Last 20 Episodes Average Reward: 230.00		Running reward: 230.88
# Episode 320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 196.78
# Episode 340 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 185.00		Running reward: 186.79
# Episode 360 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 146.57
# Episode 380 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 200.00		Running reward: 174.14
# Episode 400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 144.72
# Episode 420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 180.17
# Episode 440 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 135.00		Running reward: 149.21
# Episode 460 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 230.00		Running reward: 230.60
# Episode 480 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 85.00		Running reward: 139.92
# Episode 500 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 20.00		Running reward: 64.83
# Episode 520 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 55.00		Running reward: 60.85
# Episode 540 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 45.00		Running reward: 46.68
# Episode 560 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 60.00		Running reward: 54.52
# Episode 580 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 65.00		Running reward: 69.80
# Episode 600 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 70.00		Running reward: 68.76
# Episode 620 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 85.00		Running reward: 84.75
# Episode 640 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 75.00		Running reward: 83.98
# Episode 660 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 110.00		Running reward: 98.86
# Episode 680 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 70.00		Running reward: 85.10
# Episode 700 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 108.83
# Episode 720 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 225.00		Running reward: 178.60
# Episode 740 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 131.41
# Episode 760 completed.	Last Reward: 700.00	Last 20 Episodes Average Reward: 150.00		Running reward: 150.20
# Episode 780 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 205.00		Running reward: 201.23
# Episode 800 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 230.00		Running reward: 221.32
# Episode 820 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 130.00		Running reward: 158.39
# Episode 840 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 190.00		Running reward: 182.25
# Episode 860 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 235.00		Running reward: 217.04
# Episode 880 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 220.00		Running reward: 200.07
# Episode 900 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 120.00		Running reward: 151.26
# Episode 920 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 210.00		Running reward: 196.33
# Episode 940 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 183.01
# Episode 960 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 225.00		Running reward: 204.63
# Episode 980 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 225.00		Running reward: 212.11
# Episode 1000 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 245.00		Running reward: 236.44
# Episode 1020 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 235.00		Running reward: 223.92
# Episode 1040 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 207.36
# Episode 1060 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 145.00		Running reward: 176.15
# Episode 1080 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 183.82
# Episode 1100 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 200.00		Running reward: 198.15
# Episode 1120 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 315.00		Running reward: 304.07
# Episode 1140 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 160.00		Running reward: 205.55
# Episode 1160 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 130.00		Running reward: 151.93
# Episode 1180 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 115.00		Running reward: 121.71
# Episode 1200 completed.	Last Reward: 1200.00	Last 20 Episodes Average Reward: 185.00		Running reward: 183.64
# Episode 1220 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 210.00		Running reward: 197.27
# Episode 1240 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 290.00		Running reward: 260.04
# Episode 1260 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 215.00		Running reward: 226.50
# Episode 1280 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 215.00		Running reward: 214.71
# Episode 1300 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 225.00		Running reward: 231.90
# Episode 1320 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 235.00		Running reward: 237.92
# Episode 1340 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 160.00		Running reward: 193.28
# Episode 1360 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 300.00		Running reward: 267.15
# Episode 1380 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 215.27
# Episode 1400 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 230.00		Running reward: 222.66
# Episode 1420 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 165.00		Running reward: 180.64
# Episode 1440 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 170.00		Running reward: 169.03
# Episode 1460 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 179.17
# Episode 1480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 137.94
# Episode 1500 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 163.33
# Recompensa obtenida en el episodio: 32100.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Preguntas de análisis
#
# Teniendo en cuenta lo observado en las pruebas anteriores, reflexione acerca de las siguientes preguntas:
#
# *   ¿Es REINFORCE un algoritmo estable?
#
# *   ¿Es siempre bueno usar cualquier <i>baseline</i> en REINFORCE?
#
# *   ¿Qué efecto tiene normalizar los retornos? ¿Es similar a utilizar <i>baselines</i>?
#
# ---
#
# ## Respuestas (con los resultados obtenidos)
#
# ### Resumen de resultados
#
# Recompensas obtenidas en la **partida de validación** (video al final del entrenamiento) para cada configuración, comparadas con la política aleatoria (~7,200 en modo 0, ~13,900 en modo 2):
#
# | Configuración | Recompensa video | Pico de *running reward* (entrenamiento) | Comportamiento de la curva |
# |---|---|---|---|
# | `use_baseline=0` (sin baseline) | **30,600** | 220 ≈ ep 880 | Oscila ~50–220 todo el entrenamiento; sin tendencia clara de mejora monótona |
# | `use_baseline=1` (normalización) | 23,800 | 219 ≈ ep 460 | La más estable en el tramo medio (sostiene 150–200 entre eps 100–800) |
# | `use_baseline=2` (promedio escalar) | 23,500 | **252 ≈ ep 560** | Pico más alto, pero seguido de caída a 97; alta varianza |
# | `use_baseline=3` (red de valor) | **32,100** | 230 ≈ ep 460 | Pico fuerte y luego **colapsa a ~46 hacia ep 540**; recupera tarde |
#
# > Las cuatro configuraciones **superan ampliamente la política aleatoria** (~10,000) en el video final. Sin embargo, eso oculta el hecho de que el entrenamiento es muy ruidoso y el resultado final depende mucho del estado de la política en el momento exacto del corte.
#
# ### ¿Es REINFORCE un algoritmo estable?
#
# **No.** Aunque al final las cuatro configuraciones logran videos por encima de la política aleatoria (entre 23,500 y 32,100), las curvas de entrenamiento muestran inestabilidad clara:
#
# - **Oscilación de la *running reward* del orden del 100 % de su valor**: por ejemplo, con `use_baseline=0` la *running reward* salta entre 48 (ep 600) y 220 (ep 880); con `use_baseline=3` cae de 230 (ep 460) a **46 (ep 540)** — una pérdida de casi todo lo aprendido — antes de recuperarse hacia el final.
# - **Sin convergencia monótona**: ninguna de las curvas se "estabiliza" en un valor alto. Lo que se ve es un proceso ruidoso del que, **por suerte de cuándo se corta el entrenamiento**, salen videos buenos o malos.
# - **Sensibilidad a la semilla**: las dos corridas de `use_baseline=0` y `use_baseline=3` parten con valores muy similares en el ep 20 (`Last 20 Avg = 90` y `Running = 56.69` para ambas), pero a partir de ahí divergen completamente. El gradiente de Monte Carlo amplifica diferencias minúsculas en las primeras trayectorias.
#
# En conclusión, REINFORCE puede dar resultados aceptables si se corta en el momento adecuado, pero **no es estable**: el algoritmo no garantiza que la próxima actualización no destruya lo aprendido.
#
# ### ¿Es siempre bueno usar cualquier *baseline* en REINFORCE?
#
# **No.** Los resultados muestran que la elección del baseline puede *empeorar* el algoritmo respecto a no usar ninguno:
#
# - **`use_baseline=2` (promedio escalar)**: alcanza el pico más alto del experimento (`Running reward = 252` en ep 560), pero también el video final es el más bajo de los cuatro (23,500). La señal del baseline escalar es demasiado gruesa para guiar correctamente — favorece picos pero no mantiene la política.
# - **`use_baseline=3` (red $V_\phi(s)$)**: en teoría debería ser la opción más fuerte, y en efecto produce el mejor video (32,100). **Pero también es la curva más inestable**: colapsa a `Running reward = 46.68` en el ep 540, cayendo desde 230 — la red de valor estaba mal calibrada en ese tramo y el "baseline" se volvió ruido. El hecho de que termine bien es más suerte de cuándo se cortó la simulación que prueba de superioridad sistemática.
# - **`use_baseline=0` (sin baseline)**: a pesar de la teoría, **no es la peor opción**: video final 30,600, segundo lugar. Esto pasa porque en *Atlantis* las recompensas son grandes y positivas, así que el estimador sin baseline ya tiene una señal de gradiente útil — un baseline mal entrenado puede ser peor que ninguno.
#
# **Lección práctica**: un baseline solo ayuda si reduce la varianza más de lo que añade. Una red de valor mal entrenada o un escalar grueso pueden destruir la señal — exactamente lo que se ve en `use_baseline=3` cuando colapsa de 230 a 46.
#
# ### ¿Qué efecto tiene normalizar los retornos? ¿Es similar a utilizar *baselines*?
#
# **Es parecido pero más estable, y es lo que mejor se vio en este experimento.**
#
# - En los datos, `use_baseline=1` (normalizar retornos) es **la corrida con la curva más estable** en el tramo medio: sostiene `Running reward` entre 150 y 200 desde el ep 240 hasta el ep 800 sin colapsos, mientras que `use_baseline=3` se va a 46 en ese mismo rango. Sin embargo, **su video final es el más bajo** (23,800), porque la última fase del entrenamiento (eps 920–940) la dejó en una zona menos buena que `use_baseline=0` o `=3`.
# - Restar la media equivale a un baseline escalar (similar a `use_baseline=2`), pero **dividir por la desviación estándar** no es un baseline en sentido formal: reescala el paso de gradiente y actúa como un control adaptativo de magnitud, parecido a un *learning rate* dinámico. Esto es lo que estabiliza la curva en el medio: gradientes con magnitudes uniformes entre episodios largos y cortos.
# - **Diferencia clave con un baseline real**: la normalización es **independiente del estado**, así que no ataca la fuente principal de varianza (retornos sistemáticamente mayores en algunos estados). Por eso, en este experimento, normalizar produjo *menos colapsos* (más estable) pero también un *video final más bajo* (no aprovecha toda la información).
#
# **En resumen, con los datos de esta corrida**: `use_baseline=1` es la opción más conservadora (poca varianza, menos riesgo de colapso, pero también techo más bajo); `use_baseline=3` puede dar el mejor resultado pero a costa de inestabilidad fuerte (colapsó a 1/5 de su pico); `use_baseline=2` es el menos recomendable (alta varianza con resultado pobre); y `use_baseline=0` sorprendió siendo competitivo, lo que confirma que **REINFORCE depende más del *seed* y del momento del corte que de la elección del baseline**.

# %% [markdown]
# # Referencias
#
# [1] Sutton, R. S. and Barto, A. G. (2018). Reinforcement Learning: An Introduction. The MIT Press, second edition.
#
# [2] Gym Documentation, Atlantis. `https://gymnasium.farama.org/v0.28.1/environments/atari/atlantis/`
#
# [3] PyTorch REINFORCE example. `https://github.com/pytorch/examples/blob/main/reinforcement_learning/reinforce.py`
